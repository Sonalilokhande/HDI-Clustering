# %% [markdown]
# ### Detecting human orthologs for yeast genetic interactors of Huntingtin protein.
# #### Mason etal_2013

# %%
path <- "C:/Users/Sonali/Box Sync/Huntington Interactome/MutantHTT_Interactors/Yeast/MutantHttSuppressors_green"
setwd(path)

#####################################################
### Get the required libararies
#####################################################
library("AnnotationDbi")
library("hom.Sc.inp.db")
library("biomaRt")
library ("plyr") #### just in case.

########################################
###Biomart package installation####
#######################################
source("http://bioconductor.org/biocLite.R")
biocLite("biomaRt")
source("https://bioconductor.org/biocLite.R")
biocLite("hom.Sc.inp.db")
# 
# #########################################
# ##To view documentation for the version of this package ###
# ############################################################
# browseVignettes("biomaRt")
# 
# ###################################################
# ### code chunk number 2: biomaRt
# ###################################################
# library("biomaRt")
# listMarts()
# 
# 
# 
# ###################################################
# ### code chunk number 4: listDatasets
# ###################################################
# listDatasets(ensembl)

#############################################################
### Read the file containing the gene symbols of the organism
###############################################################

yeastEGIds <- read.table(file= "R_Input_Mason_etal2013.txt", sep = "\t", header = TRUE)

# convert your Gene Symbols to ensemble gene id and ensembl protein id for your organism

yeast = useMart(host='dec2014.archive.ensembl.org',biomart = 'ENSEMBL_MART_ENSEMBL', dataset = "scerevisiae_gene_ensembl") ### specify the dataset to use 

###################################################
### filters for the yeast dataset
###################################################
filters = listFilters(yeast)
filters[1:5,]
listFilters(yeast)

###################################################
### attributes for yeast dataset
###################################################
attributes = listAttributes(yeast)

attributes[1:5,]
listAttributes(yeast, page="feature_page")


########################################
## Get the attributes for yeast dataset 
#######################################


rawMasonENSProtIds <- getBM(c('ensembl_gene_id', 'external_gene_name', 'ensembl_peptide_id'), filters='wikigene_name', 'external_gene_name', values= yeastEGIds$AssociatedGeneName, mart=yeast) # convert Gene Symbol to ensemble gene id and ensembl protein id for your organism
length (rawMasonENSProtIds)
dim (rawMasonENSProtIds)
class(rawMasonENSProtIds)
rawMasonENSProtIds


#########################################
# remove duplicate values from the ensembl protein id column
#######################################

MasonENSProtIds <- rawMasonENSProtIds[!duplicated(rawMasonENSProtIds[,3]),]
MasonENSProtIds
dim(MasonENSProtIds)
 
##############################################
# Using the Inparanoid function to find human orthologs in form of human ensembl protein IDs#
##################################################

rawHumanProtIds <- mget(unlist(MasonENSProtIds$ensembl_peptide_id) ,hom.Sc.inpHOMSA,ifnotfound=NA)

rawHumanProtIds
class(rawHumanProtIds)
HumanProtIds <- rawHumanProtIds[!is.na(rawHumanProtIds)] ## remove all the NA values from the list
HumanProtIds
length(HumanProtIds)

##########################################################################
## Find the ensembl gene id annd hgnc symbols for your human ensembl peptide id 
## using the getBM function and the human ensembl dataset
#######################################################################

human = useMart(host='dec2014.archive.ensembl.org',biomart = 'ENSEMBL_MART_ENSEMBL', dataset = "hsapiens_gene_ensembl")
Humanorthologs <- getBM(c('ensembl_gene_id', 'hgnc_symbol', 'ensembl_peptide_id', 'entrezgene'), filters='ensembl_peptide_id', values=HumanProtIds, mart=human) # convert Gene Symbol to ensemble gene id and ensembl protein id for your organism
Humanorthologs
dim(Humanorthologs)

## run the line below if need output in text file.

# write.table(Humanorthologs, file="MasonHumanOrthologs.txt", sep="\t", col.names = NA) ### export file in text format to the folder.


##############################################################################################
##########END ################################################################################
#############################################################################################

sessionInfo()
# Out:
# Bioconductor version 3.4 (BiocInstaller 1.24.0), ?biocLite for help
# BioC_mirror: https://bioconductor.org
# Using Bioconductor 3.4 (BiocInstaller 1.24.0), R 3.3.1 (2016-06-21).
# Installing package(s) 'biomaRt'
# Warning message:
# "package 'biomaRt' is in use and will not be installed"installation path not writeable, unable to update packages: cluster, codetools,
#   foreign, lattice, Matrix, mgcv, nlme, survival
# Old packages: 'assertthat', 'curl', 'matrixStats', 'party', 'zoo'
# Bioconductor version 3.4 (BiocInstaller 1.24.0), ?biocLite for help
# BioC_mirror: https://bioconductor.org
# Using Bioconductor 3.4 (BiocInstaller 1.24.0), R 3.3.1 (2016-06-21).
# Installing package(s) 'hom.Sc.inp.db'
# installing the source package 'hom.Sc.inp.db'
#
# installation path not writeable, unable to update packages: cluster, codetools,
#   foreign, lattice, Matrix, mgcv, nlme, survival
# Old packages: 'assertthat', 'curl', 'matrixStats', 'party', 'zoo'
#   name               description
# 1 chromosome_name    Chromosome name
# 2 start              Gene Start (bp)
# 3 end                Gene End (bp)
# 4 strand             Strand
# 5 chromosomal_region Chromosome Regions (e.g 1:100:10000:-1,1:100000:200000:1)
#     name
# 1   chromosome_name
# 2   start
# 3   end
# 4   strand
# 5   chromosomal_region
# 6   with_tra_tsl
# 7   with_tra_appris_pi
# 8   with_tra_gencode_basic
# 9   with_ec_number
# 10  with_embl
# 11  with_entrezgene
# 12  with_go_go
# 13  with_go_id
# 14  with_goslim_goa
# 15  with_merops
# 16  with_pdb
# 17  with_protein_id
# 18  with_refseq_dna
# 19  with_refseq_mrna
# 20  with_refseq_peptide
# 21  with_sgd_gene
# 22  with_sgd_transcript
# 23  with_uniparc
# 24  with_ox_uniprotswissprot
# 25  with_uniprotsptrembl
# 26  with_ox_uniprotsptrembl
# 27  with_wikigene
# 28  with_affy_yeast_2
# 29  with_affy_yg_s98
# 30  ensembl_gene_id
# ... ...
# 137 with_prosite
# 138 with_profile
# 139 with_tmhmm
# 140 with_tigrfam
# 141 with_superfamily
# 142 with_smart
# 143 with_signalp
# 144 with_low_complexity
# 145 with_pirsf
# 146 with_coil
# 147 with_interpro
# 148 with_protein_feature_pfam
# 149 with_protein_feature_prints
# 150 tigrfam
# 151 gene3d
# 152 superfamily
# 153 smart
# 154 pirsf
# 155 family
# 156 pfam
# 157 hmmpanther
# 158 prints
# 159 profile
# 160 prosite
# 161 interpro
# 162 with_transmembrane_domain
# 163 with_signal_domain
# 164 germ_line_variation_source
# 165 with_validated_snp
# 166 so_parent_name
#     description
# 1   Chromosome name
# 2   Gene Start (bp)
# 3   Gene End (bp)
# 4   Strand
# 5   Chromosome Regions (e.g 1:100:10000:-1,1:100000:200000:1)
# 6   with Transcript Support Level (TSL)
# 7   with APPRIS principal isoform annotation
# 8   with GENCODE basic annotation
# 9   with EC number(s)
# 10  with EMBL ID(s)
# 11  with EntrezGene ID(s)
# 12  with GO ID(s)
# 13  with GO Term Accession(s)
# 14  with GOSlim GOA(s)
# 15  with MEROPS ID(s)
# 16  with PDB ID(s)
# 17  with protein(Genbank) ID(s)
# 18  with RefSeq DNA ID(s)
# 19  with RefSeq mRNA ID(s)
# 20  with RefSeq protein ID(s)
# 21  with SGD gene ID(s)
# 22  with SGD transcript ID(s)
# 23  with UniParc ID(s)
# 24  with UniProtSWISSPROT ID(s)
# 25  with UniProtKB/TrEMBL Accession(s)
# 26  with UniProtSPTREMBL ID(s)
# 27  with WikiGene ID(s)
# 28  with Affymetrix Microarray yeast 2 probeset ID(s)
# 29  with Affymetrix Microarray yg s98 probeset ID(s)
# 30  Ensembl Gene ID(s) [e.g. ENSG00000139618]
# ... ...
# 137 with Protein feature scanprosite ID(s)
# 138 with Protein feature pfscan ID(s)
# 139 with Protein feature tmhmm ID(s)
# 140 with Protein feature tigrfam ID(s)
# 141 with Protein feature superfamily ID(s)
# 142 with Protein feature smart ID(s)
# 143 with Protein feature signalp ID(s)
# 144 with Protein feature seg ID(s)
# 145 with Protein feature pirsf ID(s)
# 146 with Protein feature ncoils ID(s)
# 147 with InterPro ID(s)
# 148 with PFAM ID(s)
# 149 with PRINTS ID(s)
# 150 TIGRfam ID(s) [e.g. TIGR00172]
# 151 Gene3D ID(s) [e.g. G3DSA:2.130.10.10]
# 152 Superfamily ID(s) [e.g. SSF47095]
# 153 SMART ID(s) [e.g. SM00398]
# 154 PIRSF ID(s) [e.g. PIRSF037653]
# 155 Ensembl Protein Family ID(s) [e.g. ENSFM00250000000002]
# 156 PFAM ID(s) [e.g. PF00046]
# 157 HMMPanther ID(s) [e.g. PTHR12369]
# 158 PRINTS ID(s) [e.g. PR00194]
# 159 PROFILE ID(s) [e.g. PS50313]
# 160 PROSITE ID(s) [e.g. PS00028]
# 161 Interpro ID(s) [e.g. IPR007087]
# 162 Transmembrane domains
# 163 Signal domains
# 164 limit to genes with germline variation data sources
# 165 Associated with validated SNPs
# 166 Parent term name
#   name                  description           page
# 1 ensembl_gene_id       Ensembl Gene ID       feature_page
# 2 ensembl_transcript_id Ensembl Transcript ID feature_page
# 3 ensembl_peptide_id    Ensembl Protein ID    feature_page
# 4 ensembl_exon_id       Ensembl Exon ID       feature_page
# 5 description           Description           feature_page
#     name                            description
# 1   ensembl_gene_id                 Ensembl Gene ID
# 2   ensembl_transcript_id           Ensembl Transcript ID
# 3   ensembl_peptide_id              Ensembl Protein ID
# 4   ensembl_exon_id                 Ensembl Exon ID
# 5   description                     Description
# 6   chromosome_name                 Chromosome Name
# 7   start_position                  Gene Start (bp)
# 8   end_position                    Gene End (bp)
# 9   strand                          Strand
# 10  band                            Band
# 11  transcript_start                Transcript Start (bp)
# 12  transcript_end                  Transcript End (bp)
# 13  transcription_start_site        Transcription Start Site (TSS)
# 14  transcript_length               Transcript length
# 15  transcript_tsl                  Transcript Support Level (TSL)
# 16  transcript_gencode_basic        GENCODE basic annotation
# 17  transcript_appris_pi            APPRIS principal isoform annotation
# 18  external_gene_name              Associated Gene Name
# 19  external_gene_source            Associated Gene Source
# 20  external_transcript_name        Associated Transcript Name
# 21  external_transcript_source_name Associated Transcript Source
# 22  transcript_count                Transcript count
# 23  percentage_gc_content           % GC content
# 24  gene_biotype                    Gene type
# 25  transcript_biotype              Transcript type
# 26  source                          Source (gene)
# 27  transcript_source               Source (transcript)
# 28  status                          Status (gene)
# 29  transcript_status               Status (transcript)
# 30  version                         Version (gene)
# ... ...                             ...
# 48  sgd_gene                        SGD Gene
# 49  sgd_transcript                  SGD Transcript
# 50  uniparc                         UniParc
# 51  uniprot_sptrembl                UniProt/TrEMBL Accession
# 52  uniprot_swissprot               UniProt/SwissProt ID
# 53  uniprot_swissprot_accession     UniProt/SwissProt Accession
# 54  wikigene_name                   WikiGene Name
# 55  wikigene_id                     WikiGene ID
# 56  wikigene_description            WikiGene Description
# 57  affy_yeast_2                    Affy yeast 2 probeset
# 58  affy_yg_s98                     Affy yg s98 probeset
# 59  family                          Ensembl Protein Family ID(s)
# 60  family_description              Ensembl Family Description
# 61  pirsf                           PIRSF SuperFamily ID
# 62  superfamily                     Superfamily ID
# 63  smart                           SMART ID
# 64  profile                         PROFILE ID
# 65  prosite                         PROSITE ID
# 66  prints                          PRINTS ID
# 67  pfam                            PFAM ID
# 68  tigrfam                         TIGRFam ID
# 69  gene3d                          Gene3D ID
# 70  hmmpanther                      HMMPanther ID
# 71  interpro                        Interpro ID
# 72  interpro_short_description      Interpro Short Description
# 73  interpro_description            Interpro Description
# 74  low_complexity                  Low complexity
# 75  transmembrane_domain            Transmembrane domain
# 76  signal_domain                   Signal domain
# 77  ncoils                          Ncoils
#     page
# 1   feature_page
# 2   feature_page
# 3   feature_page
# 4   feature_page
# 5   feature_page
# 6   feature_page
# 7   feature_page
# 8   feature_page
# 9   feature_page
# 10  feature_page
# 11  feature_page
# 12  feature_page
# 13  feature_page
# 14  feature_page
# 15  feature_page
# 16  feature_page
# 17  feature_page
# 18  feature_page
# 19  feature_page
# 20  feature_page
# 21  feature_page
# 22  feature_page
# 23  feature_page
# 24  feature_page
# 25  feature_page
# 26  feature_page
# 27  feature_page
# 28  feature_page
# 29  feature_page
# 30  feature_page
# ... ...
# 48  feature_page
# 49  feature_page
# 50  feature_page
# 51  feature_page
# 52  feature_page
# 53  feature_page
# 54  feature_page
# 55  feature_page
# 56  feature_page
# 57  feature_page
# 58  feature_page
# 59  feature_page
# 60  feature_page
# 61  feature_page
# 62  feature_page
# 63  feature_page
# 64  feature_page
# 65  feature_page
# 66  feature_page
# 67  feature_page
# 68  feature_page
# 69  feature_page
# 70  feature_page
# 71  feature_page
# 72  feature_page
# 73  feature_page
# 74  feature_page
# 75  feature_page
# 76  feature_page
# 77  feature_page
# [1] 3
# [1] 211   3
# [1] "data.frame"
#     ensembl_gene_id external_gene_name ensembl_peptide_id
# 1   YHR116W         COX23              YHR116W
# 2   YNL218W         MGS1               YNL218W
# 3   YOR026W         BUB3               YOR026W
# 4   YML116W         ATR1               YML116W
# 5   YGL155W         CDC43              YGL155W
# 6   YDL125C         HNT1               YDL125C
# 7   YGL162W         SUT1               YGL162W
# 8   YGL047W         ALG13              YGL047W
# 9   YMR203W         TOM40              YMR203W
# 10  YEL072W         RMD6               YEL072W
# 11  YGL015C                            YGL015C
# 12  YIL043C         CBR1               YIL043C
# 13  YPR147C                            YPR147C
# 14  YHR128W         FUR1               YHR128W
# 15  YDR225W         HTA1               YDR225W
# 16  YDR482C         CWC21              YDR482C
# 17  YMR186W         HSC82              YMR186W
# 18  YJR145C         RPS4A              YJR145C
# 19  YHR041C         SRB2               YHR041C
# 20  YFL065C                            YFL065C
# 21  YHL026C                            YHL026C
# 22  YLR459W         GAB1               YLR459W
# 23  YOR283W                            YOR283W
# 24  YEL033W         MTC7               YEL033W
# 25  YKR069W         MET1               YKR069W
# 26  Q0275           COX3               Q0275
# 27  YBR128C         ATG14              YBR128C
# 28  YDR540C         IRC4               YDR540C
# 29  YLR364W         GRX8               YLR364W
# 30  YJR152W         DAL5               YJR152W
# ... ...             ...                ...
# 182 YER183C         FAU1               YER183C
# 183 YLR437C         DIF1               YLR437C
# 184 YFR017C         IGD1               YFR017C
# 185 YCR047C         BUD23              YCR047C
# 186 YDR423C         CAD1               YDR423C
# 187 YHR203C         RPS4B              YHR203C
# 188 YDR056C                            YDR056C
# 189 YOL026C         MIM1               YOL026C
# 190 YBR091C         TIM12              YBR091C
# 191 YKL026C         GPX1               YKL026C
# 192 YNL155W                            YNL155W
# 193 YJR125C         ENT3               YJR125C
# 194 YNR027W         BUD17              YNR027W
# 195 YPR182W         SMX3               YPR182W
# 196 YGR262C         BUD32              YGR262C
# 197 YEL059C-A       SOM1               YEL059C-A
# 198 YJR086W         STE18              YJR086W
# 199 YBL072C         RPS8A              YBL072C
# 200 YGR008C         STF2               YGR008C
# 201 YEL057C                            YEL057C
# 202 YFL049W         SWP82              YFL049W
# 203 YHL011C         PRS3               YHL011C
# 204 YOR045W         TOM6               YOR045W
# 205 YPL282C         PAU22              YPL282C
# 206 YDR370C                            YDR370C
# 207 YCL042W                            YCL042W
# 208 YIR022W         SEC11              YIR022W
# 209 YGR277C         CAB4               YGR277C
# 210 YJR050W         ISY1               YJR050W
# 211 YER134C                            YER134C
#     ensembl_gene_id external_gene_name ensembl_peptide_id
# 1   YHR116W         COX23              YHR116W
# 2   YNL218W         MGS1               YNL218W
# 3   YOR026W         BUB3               YOR026W
# 4   YML116W         ATR1               YML116W
# 5   YGL155W         CDC43              YGL155W
# 6   YDL125C         HNT1               YDL125C
# 7   YGL162W         SUT1               YGL162W
# 8   YGL047W         ALG13              YGL047W
# 9   YMR203W         TOM40              YMR203W
# 10  YEL072W         RMD6               YEL072W
# 11  YGL015C                            YGL015C
# 12  YIL043C         CBR1               YIL043C
# 13  YPR147C                            YPR147C
# 14  YHR128W         FUR1               YHR128W
# 15  YDR225W         HTA1               YDR225W
# 16  YDR482C         CWC21              YDR482C
# 17  YMR186W         HSC82              YMR186W
# 18  YJR145C         RPS4A              YJR145C
# 19  YHR041C         SRB2               YHR041C
# 20  YFL065C                            YFL065C
# 21  YHL026C                            YHL026C
# 22  YLR459W         GAB1               YLR459W
# 23  YOR283W                            YOR283W
# 24  YEL033W         MTC7               YEL033W
# 25  YKR069W         MET1               YKR069W
# 26  Q0275           COX3               Q0275
# 27  YBR128C         ATG14              YBR128C
# 28  YDR540C         IRC4               YDR540C
# 29  YLR364W         GRX8               YLR364W
# 30  YJR152W         DAL5               YJR152W
# ... ...             ...                ...
# 182 YER183C         FAU1               YER183C
# 183 YLR437C         DIF1               YLR437C
# 184 YFR017C         IGD1               YFR017C
# 185 YCR047C         BUD23              YCR047C
# 186 YDR423C         CAD1               YDR423C
# 187 YHR203C         RPS4B              YHR203C
# 188 YDR056C                            YDR056C
# 189 YOL026C         MIM1               YOL026C
# 190 YBR091C         TIM12              YBR091C
# 191 YKL026C         GPX1               YKL026C
# 192 YNL155W                            YNL155W
# 193 YJR125C         ENT3               YJR125C
# 194 YNR027W         BUD17              YNR027W
# 195 YPR182W         SMX3               YPR182W
# 196 YGR262C         BUD32              YGR262C
# 197 YEL059C-A       SOM1               YEL059C-A
# 198 YJR086W         STE18              YJR086W
# 199 YBL072C         RPS8A              YBL072C
# 200 YGR008C         STF2               YGR008C
# 201 YEL057C                            YEL057C
# 202 YFL049W         SWP82              YFL049W
# 203 YHL011C         PRS3               YHL011C
# 204 YOR045W         TOM6               YOR045W
# 205 YPL282C         PAU22              YPL282C
# 206 YDR370C                            YDR370C
# 207 YCL042W                            YCL042W
# 208 YIR022W         SEC11              YIR022W
# 209 YGR277C         CAB4               YGR277C
# 210 YJR050W         ISY1               YJR050W
# 211 YER134C                            YER134C
# [1] 211   3
# $YHR116W
# [1] NA
#
# $YNL218W
# [1] "ENSP00000370150"
#
# $YOR026W
# [1] NA
#
# $YML116W
# [1] NA
#
# $YGL155W
# [1] NA
#
# $YDL125C
# [1] NA
#
# $YGL162W
# [1] NA
#
# $YGL047W
# [1] NA
#
# $YMR203W
# [1] "ENSP00000252487"
#
# $YEL072W
# [1] NA
#
# $YGL015C
# [1] NA
#
# $YIL043C
# [1] NA
#
# $YPR147C
# [1] NA
#
# $YHR128W
# [1] "ENSP00000362481"
#
# $YDR225W
# [1] NA
#
# $YDR482C
# [1] NA
#
# $YMR186W
# [1] NA
#
# $YJR145C
# [1] "ENSP00000362744"
#
# $YHR041C
# [1] NA
#
# $YFL065C
# [1] NA
#
# $YHL026C
# [1] NA
#
# $YLR459W
# [1] "ENSP00000217446"
#
# $YOR283W
# [1] NA
#
# $YEL033W
# [1] NA
#
# $YKR069W
# [1] NA
#
# $Q0275
# [1] "ENSP00000386789" "ENSP00000354982"
#
# $YBR128C
# [1] NA
#
# $YDR540C
# [1] NA
#
# $YLR364W
# [1] NA
#
# $YJR152W
# [1] NA
#
# $YLR141W
# [1] NA
#
# $YCR105W
# [1] NA
#
# $YDL136W
# [1] "ENSP00000259469"
#
# $YNR010W
# [1] NA
#
# $YDR249C
# [1] NA
#
# $YDL168W
# [1] NA
#
# $YDL114W
# [1] NA
#
# $YMR300C
# [1] "ENSP00000264220"
#
# $YGL161C
# [1] "ENSP00000072644" "ENSP00000253031"
#
# $YGR070W
# [1] NA
#
# $YGR281W
# [1] NA
#
# $YOR182C
# [1] NA
#
# $YIL162W
# [1] NA
#
# $YMR059W
# [1] NA
#
# $YFR044C
# [1] "ENSP00000325548"
#
# $YOR171C
# [1] NA
#
# $YOR031W
# [1] NA
#
# $YLR359W
# [1] "ENSP00000216194"
#
# $YLR038C
# [1] "ENSP00000376037"
#
# $`YLR287C-A`
# [1] NA
#
# $`YHR218W-A`
# [1] NA
#
# $`YHR005C-A`
# [1] "ENSP00000257245"
#
# $YER126C
# [1] "ENSP00000296802"
#
# $YHL043W
# [1] NA
#
# $YOR101W
# [1] NA
#
# $YML129C
# [1] NA
#
# $YDR418W
# [1] "ENSP00000354739"
#
# $YCR038C
# [1] "ENSP00000338437"
#
# $YLL049W
# [1] NA
#
# $YPL069C
# [1] "ENSP00000351852"
#
# $YGR095C
# [1] "ENSP00000221233"
#
# $YNL129W
# [1] "ENSP00000168977"
#
# $YGR106C
# [1] NA
#
# $YGL145W
# [1] NA
#
# $YIL069C
# [1] "ENSP00000361435"
#
# $YBR192W
# [1] NA
#
# $YDL217C
# [1] "ENSP00000320236"
#
# $YJL189W
# [1] "ENSP00000355315"
#
# $YBR018C
# [1] "ENSP00000368119"
#
# $YDR500C
# [1] NA
#
# $YMR096W
# [1] NA
#
# $YAL049C
# [1] "ENSP00000296658"
#
# $YPL112C
# [1] NA
#
# $YIL044C
# [1] NA
#
# $YML051W
# [1] NA
#
# $YKL098W
# [1] NA
#
# $YDR016C
# [1] NA
#
# $YPL018W
# [1] NA
#
# $YMR321C
# [1] NA
#
# $YHR191C
# [1] NA
#
# $YPR096C
# [1] NA
#
# $YER102W
# [1] "ENSP00000361288"
#
# $YNL220W
# [1] "ENSP00000355493"
#
# $YGR059W
# [1] NA
#
# $YML053C
# [1] NA
#
# $YDR270W
# [1] NA
#
# $YOL024W
# [1] NA
#
# $YER074W
# [1] "ENSP00000361435"
#
# $YOL131W
# [1] NA
#
# $YNL182C
# [1] "ENSP00000251289"
#
# $YNL130C
# [1] NA
#
# $YPR031W
# [1] NA
#
# $YMR159C
# [1] NA
#
# $YLR306W
# [1] NA
#
# $YOR234C
# [1] "ENSP00000330165"
#
# $YLR036C
# [1] NA
#
# $YDL226C
# [1] NA
#
# $YLR344W
# [1] "ENSP00000265100"
#
# $YMR079W
# [1] NA
#
# $YJL035C
# [1] NA
#
# $YJL173C
# [1] NA
#
# $YDL066W
# [1] "ENSP00000260985" "ENSP00000331897"
#
# $YJL137C
# [1] "ENSP00000381786" "ENSP00000340736"
#
# $YGR082W
# [1] "ENSP00000355566"
#
# $YCL005W
# [1] NA
#
# $YER179W
# [1] "ENSP00000216024"
#
# $YBR187W
# [1] "ENSP00000370736"
#
# $YIL064W
# [1] "ENSP00000357830"
#
# $YER057C
# [1] "ENSP00000254878"
#
# $YHR021C
# [1] "ENSP00000357555"
#
# $YMR143W
# [1] NA
#
# $YGR183C
# [1] NA
#
# $YHR083W
# [1] NA
#
# $`YEL020W-A`
# [1] NA
#
# $YEL054C
# [1] "ENSP00000354739"
#
# $YHR196W
# [1] NA
#
# $YNR069C
# [1] NA
#
# $YLR170C
# [1] NA
#
# $YFR057W
# [1] NA
#
# $YOR332W
# [1] "ENSP00000253413"
#
# $YKR074W
# [1] "ENSP00000386302"
#
# $YOL114C
# [1] "ENSP00000301585"
#
# $YNL288W
# [1] "ENSP00000273064"
#
# $YOR302W
# [1] NA
#
# $YOR241W
# [1] NA
#
# $YPL042C
# [1] NA
#
# $`YKL006C-A`
# [1] NA
#
# $YJR097W
# [1] "ENSP00000379279"
#
# $YGR037C
# [1] "ENSP00000386486"
#
# $YBR191W
# [1] "ENSP00000346027"
#
# $YLL009C
# [1] "ENSP00000261070"
#
# $YFL057C
# [1] NA
#
# $YDR226W
# [1] "ENSP00000346921"
#
# $YGR275W
# [1] NA
#
# $YDL191W
# [1] "ENSP00000259469"
#
# $YLR102C
# [1] NA
#
# $YHR213W
# [1] NA
#
# $YBL112C
# [1] NA
#
# $`YML058W-A`
# [1] NA
#
# $YPR085C
# [1] NA
#
# $YGR247W
# [1] NA
#
# $YDR373W
# [1] NA
#
# $YER159C
# [1] NA
#
# $YBR098W
# [1] NA
#
# $YHR005C
# [1] NA
#
# $YER018C
# [1] NA
#
# $YDR242W
# [1] NA
#
# $YPL100W
# [1] NA
#
# $YGR029W
# [1] NA
#
# $YLR010C
# [1] NA
#
# $YDR202C
# [1] NA
#
# $YIL132C
# [1] NA
#
# $YML095C
# [1] NA
#
# $YGL223C
# [1] NA
#
# $YPL178W
# [1] "ENSP00000326806"
#
# $YOR068C
# [1] NA
#
# $YNL259C
# [1] "ENSP00000316854"
#
# $`YPR133W-A`
# [1] NA
#
# $YGL196W
# [1] NA
#
# $YGR230W
# [1] NA
#
# $YGL262W
# [1] NA
#
# $YOR394W
# [1] NA
#
# $YPL199C
# [1] NA
#
# $YPR004C
# [1] "ENSP00000267950"
#
# $YMR055C
# [1] NA
#
# $YPL179W
# [1] NA
#
# $YLR215C
# [1] "ENSP00000281141"
#
# $YER187W
# [1] NA
#
# $YGR252W
# [1] NA
#
# $YMR180C
# [1] NA
#
# $YLR451W
# [1] NA
#
# $YOR221C
# [1] NA
#
# $YOR128C
# [1] "ENSP00000264221"
#
# $YDL053C
# [1] NA
#
# $YDR530C
# [1] NA
#
# $YAR015W
# [1] NA
#
# $YIR037W
# [1] NA
#
# $YDL083C
# [1] NA
#
# $YIR036C
# [1] NA
#
# $YBL107C
# [1] NA
#
# $YKR103W
# [1] NA
#
# $YER183C
# [1] "ENSP00000258874"
#
# $YLR437C
# [1] NA
#
# $YFR017C
# [1] NA
#
# $YCR047C
# [1] "ENSP00000265758"
#
# $YDR423C
# [1] NA
#
# $YHR203C
# [1] "ENSP00000362744"
#
# $YDR056C
# [1] NA
#
# $YOL026C
# [1] NA
#
# $YBR091C
# [1] NA
#
# $YKL026C
# [1] NA
#
# $YNL155W
# [1] "ENSP00000220669"
#
# $YJR125C
# [1] NA
#
# $YNR027W
# [1] NA
#
# $YPR182W
# [1] "ENSP00000266735"
#
# $YGR262C
# [1] "ENSP00000361186"
#
# $`YEL059C-A`
# [1] NA
#
# $YJR086W
# [1] NA
#
# $YBL072C
# [1] "ENSP00000361288"
#
# $YGR008C
# [1] NA
#
# $YEL057C
# [1] NA
#
# $YFL049W
# [1] NA
#
# $YHL011C
# [1] NA
#
# $YOR045W
# [1] NA
#
# $YPL282C
# [1] NA
#
# $YDR370C
# [1] NA
#
# $YCL042W
# [1] NA
#
# $YIR022W
# [1] "ENSP00000268220"
#
# $YGR277C
# [1] NA
#
# $YJR050W
# [1] NA
#
# $YER134C
# [1] "ENSP00000288087"
# [1] "list"
# $YNL218W
# [1] "ENSP00000370150"
#
# $YMR203W
# [1] "ENSP00000252487"
#
# $YHR128W
# [1] "ENSP00000362481"
#
# $YJR145C
# [1] "ENSP00000362744"
#
# $YLR459W
# [1] "ENSP00000217446"
#
# $Q0275
# [1] "ENSP00000386789" "ENSP00000354982"
#
# $YDL136W
# [1] "ENSP00000259469"
#
# $YMR300C
# [1] "ENSP00000264220"
#
# $YGL161C
# [1] "ENSP00000072644" "ENSP00000253031"
#
# $YFR044C
# [1] "ENSP00000325548"
#
# $YLR359W
# [1] "ENSP00000216194"
#
# $YLR038C
# [1] "ENSP00000376037"
#
# $`YHR005C-A`
# [1] "ENSP00000257245"
#
# $YER126C
# [1] "ENSP00000296802"
#
# $YDR418W
# [1] "ENSP00000354739"
#
# $YCR038C
# [1] "ENSP00000338437"
#
# $YPL069C
# [1] "ENSP00000351852"
#
# $YGR095C
# [1] "ENSP00000221233"
#
# $YNL129W
# [1] "ENSP00000168977"
#
# $YIL069C
# [1] "ENSP00000361435"
#
# $YDL217C
# [1] "ENSP00000320236"
#
# $YJL189W
# [1] "ENSP00000355315"
#
# $YBR018C
# [1] "ENSP00000368119"
#
# $YAL049C
# [1] "ENSP00000296658"
#
# $YER102W
# [1] "ENSP00000361288"
#
# $YNL220W
# [1] "ENSP00000355493"
#
# $YER074W
# [1] "ENSP00000361435"
#
# $YNL182C
# [1] "ENSP00000251289"
#
# $YOR234C
# [1] "ENSP00000330165"
#
# $YLR344W
# [1] "ENSP00000265100"
#
# $YDL066W
# [1] "ENSP00000260985" "ENSP00000331897"
#
# $YJL137C
# [1] "ENSP00000381786" "ENSP00000340736"
#
# $YGR082W
# [1] "ENSP00000355566"
#
# $YER179W
# [1] "ENSP00000216024"
#
# $YBR187W
# [1] "ENSP00000370736"
#
# $YIL064W
# [1] "ENSP00000357830"
#
# $YER057C
# [1] "ENSP00000254878"
#
# $YHR021C
# [1] "ENSP00000357555"
#
# $YEL054C
# [1] "ENSP00000354739"
#
# $YOR332W
# [1] "ENSP00000253413"
#
# $YKR074W
# [1] "ENSP00000386302"
#
# $YOL114C
# [1] "ENSP00000301585"
#
# $YNL288W
# [1] "ENSP00000273064"
#
# $YJR097W
# [1] "ENSP00000379279"
#
# $YGR037C
# [1] "ENSP00000386486"
#
# $YBR191W
# [1] "ENSP00000346027"
#
# $YLL009C
# [1] "ENSP00000261070"
#
# $YDR226W
# [1] "ENSP00000346921"
#
# $YDL191W
# [1] "ENSP00000259469"
#
# $YPL178W
# [1] "ENSP00000326806"
#
# $YNL259C
# [1] "ENSP00000316854"
#
# $YPR004C
# [1] "ENSP00000267950"
#
# $YLR215C
# [1] "ENSP00000281141"
#
# $YOR128C
# [1] "ENSP00000264221"
#
# $YER183C
# [1] "ENSP00000258874"
#
# $YCR047C
# [1] "ENSP00000265758"
#
# $YHR203C
# [1] "ENSP00000362744"
#
# $YNL155W
# [1] "ENSP00000220669"
#
# $YPR182W
# [1] "ENSP00000266735"
#
# $YGR262C
# [1] "ENSP00000361186"
#
# $YBL072C
# [1] "ENSP00000361288"
#
# $YIR022W
# [1] "ENSP00000268220"
#
# $YER134C
# [1] "ENSP00000288087"
# [1] 63
#     ensembl_gene_id hgnc_symbol ensembl_peptide_id entrezgene
# 1   ENSG00000058799 YIPF1       ENSP00000072644        54432
# 2   ENSG00000077009 NMRK2       ENSP00000168977        27231
# 3   ENSG00000100206 DMC1        ENSP00000216024        11144
# 4   ENSG00000239900 ADSL        ENSP00000216194          158
# 5   ENSG00000101464 PIGU        ENSP00000217446       128869
# 6   ENSG00000104231 ZFAND1      ENSP00000220669        79752
# 7   ENSG00000077348 EXOSC5      ENSP00000221233        56915
# 8   ENSG00000065268 WDR18       ENSP00000251289        57418
# 9   ENSG00000130204 TOMM40      ENSP00000252487        10452
# 10  ENSG00000130733 YIPF2       ENSP00000253031        78992
# 11  ENSG00000131100 ATP6V1E1    ENSP00000253413          529
# 12  ENSG00000132541 HRSP12      ENSP00000254878        10247
# 13  ENSG00000134809 TIMM10      ENSP00000257245        26519
# 14  ENSG00000136371 MTHFS       ENSP00000258874        10588
# 15  ENSG00000136942 RPL35       ENSP00000259469        11224
# 16  ENSG00000138413 IDH1        ENSP00000260985         3417
# 17  ENSG00000138495 COX17       ENSP00000261070        10063
# 18  ENSG00000128059 PPAT        ENSP00000264220         5471
# 19  ENSG00000128050 PAICS       ENSP00000264221        10606
# 20  ENSG00000128050 PAICS       ENSP00000264221    102725410
# 21  ENSG00000037241 RPL26L1     ENSP00000265100        51121
# 22  ENSG00000071462 WBSCR22     ENSP00000265758       114049
# 23  ENSG00000139343 SNRPF       ENSP00000266735         6636
# 24  ENSG00000140374 ETFA        ENSP00000267950         2108
# 25  ENSG00000140612 SEC11A      ENSP00000268220        23478
# 26  ENSG00000140612 SEC11A      ENSP00000268220    102723931
# 27  ENSG00000144580 RQCD1       ENSP00000273064         9125
# 28  ENSG00000151465 CDC123      ENSP00000281141         8872
# 29  ENSG00000213920 MDP1        ENSP00000288087       145553
# 30  ENSG00000164237 CMBL        ENSP00000296658       134147
# ... ...             ...         ...                ...
# 33  ENSG00000177556 ATOX1       ENSP00000316854       475
# 34  ENSG00000177370 TIMM22      ENSP00000320236     29928
# 35  ENSG00000133313 CNDP2       ENSP00000325548     55748
# 36  ENSG00000114503 NCBP2       ENSP00000326806     22916
# 37  ENSG00000182054 IDH2        ENSP00000331897      3418
# 38  ENSG00000138670 RASGEF1B    ENSP00000338437    153020
# 39  ENSG00000163754 GYG1        ENSP00000340736      2992
# 40  ENSG00000122026 RPL21       ENSP00000346027      6144
# 41  ENSG00000122026 RPL21       ENSP00000346027     26771
# 42  ENSG00000122026 RPL21       ENSP00000346027    619499
# 43  ENSG00000004455 AK2         ENSP00000346921       204
# 44  ENSG00000152904 GGPS1       ENSP00000351852      9453
# 45  ENSG00000197958 RPL12       ENSP00000354739      6136
# 46  ENSG00000198938 MT-CO3      ENSP00000354982      4514
# 47  ENSG00000198918 RPL39       ENSP00000355315      6170
# 48  ENSG00000035687 ADSS        ENSP00000355493       159
# 49  ENSG00000173726 TOMM20      ENSP00000355566      9804
# 50  ENSG00000177954 RPS27       ENSP00000357555      6232
# 51  ENSG00000172315 TP53RK      ENSP00000361186    112858
# 52  ENSG00000138326 RPS24       ENSP00000361435      6229
# 53  ENSG00000094841 UPRT        ENSP00000362481    139596
# 54  ENSG00000198034 RPS4X       ENSP00000362744      6191
# 55  ENSG00000213930 GALT        ENSP00000368119      2592
# 56  ENSG00000124535 WRNIP1      ENSP00000370150     56897
# 57  ENSG00000134851 TMEM165     ENSP00000370736     55858
# 58  ENSG00000126267 COX6B1      ENSP00000376037      1340
# 59  ENSG00000170946 DNAJC24     ENSP00000379279    120526
# 60  ENSG00000056998 GYG2        ENSP00000381786      8908
# 61  ENSG00000186132 C2orf76     ENSP00000386302    130355
# 62  ENSG00000155368 DBI         ENSP00000386486      1622
# [1] 62  4
# R version 3.3.1 (2016-06-21)
# Platform: x86_64-w64-mingw32/x64 (64-bit)
# Running under: Windows 10 x64 (build 14393)
#
# locale:
# [1] LC_COLLATE=English_United States.1252
# [2] LC_CTYPE=English_United States.1252
# [3] LC_MONETARY=English_United States.1252
# [4] LC_NUMERIC=C
# [5] LC_TIME=English_United States.1252
#
# attached base packages:
# [1] parallel  stats4    stats     graphics  grDevices utils     datasets
# [8] methods   base
#
# other attached packages:
# [1] plyr_1.8.4           biomaRt_2.30.0       hom.Sc.inp.db_3.1.2
# [4] AnnotationDbi_1.36.2 IRanges_2.8.2        S4Vectors_0.12.2
# [7] Biobase_2.34.0       BiocGenerics_0.20.0  BiocInstaller_1.24.0
#
# loaded via a namespace (and not attached):
#  [1] Rcpp_0.12.10        magrittr_1.5        uuid_0.1-2
#  [4] R6_2.2.0            stringr_1.2.0       tools_3.3.1
#  [7] DBI_0.6-1           digest_0.6.12       crayon_1.3.2
# [10] IRdisplay_0.4.4     repr_0.12.0         bitops_1.0-6
# [13] RCurl_1.95-4.8      IRkernel_0.8.6.9000 memoise_1.0.0
# [16] evaluate_0.10       RSQLite_1.1-2       pbdZMQ_0.2-5
# [19] stringi_1.1.5       XML_3.98-1.6        jsonlite_1.4

# %% [markdown]
# #### Giorgini et al_2005

# %%
path <- "C:/Users/Sonali/Box Sync/Huntington Interactome/MutantHTT_Interactors/Yeast/MutantHttSuppressors_green"
setwd(path)

#####################################################
### Get the required libararies
#####################################################
library("AnnotationDbi")
library("hom.Sc.inp.db")
library("biomaRt")
library ("plyr") #### just in case.

########################################
###Biomart package installation####
#######################################
# source("http://bioconductor.org/biocLite.R")
# biocLite("biomaRt")
# 
# #########################################
# ##To view documentation for the version of this package ###
# ############################################################
# browseVignettes("biomaRt")
# 
# ###################################################
# ### code chunk number 2: biomaRt
# ###################################################
# library("biomaRt")
# listMarts()
# 
# 
# 
# ###################################################
# ### code chunk number 4: listDatasets
# ###################################################
# listDatasets(ensembl)

#############################################################
### Read the file containing the gene symbols of the organism
###############################################################

yeastEGIds <- read.table(file= "R_Input_Giorgini_etal2005.txt", sep = "\t", header = TRUE)

# convert your Gene Symbols to ensemble gene id and ensembl protein id for your organism

yeast = useMart(host='dec2014.archive.ensembl.org',biomart = 'ENSEMBL_MART_ENSEMBL', dataset = "scerevisiae_gene_ensembl") ### specify the dataset to use 

###################################################
### filters for the yeast dataset
###################################################
filters = listFilters(yeast)
filters[1:5,]
listFilters(yeast)

###################################################
### attributes for yeast dataset
###################################################
attributes = listAttributes(yeast)

attributes[1:5,]
listAttributes(yeast, page="feature_page")


########################################
## Get the attributes for yeast dataset 
#######################################


rawGiorginiENSProtIds <- getBM(c('ensembl_gene_id', 'external_gene_name', 'ensembl_peptide_id'), filters='wikigene_name', 'external_gene_name', values= yeastEGIds$Suppressors, mart=yeast) # convert Gene Symbol to ensemble gene id and ensembl protein id for your organism
length (rawGiorginiENSProtIds)
dim (rawGiorginiENSProtIds)
class(rawGiorginiENSProtIds)
rawGiorginiENSProtIds


#########################################
# remove duplicate values from the ensembl protein id column
#######################################

GiorginiENSProtIds <- rawGiorginiENSProtIds[!duplicated(rawGiorginiENSProtIds[,3]),]
GiorginiENSProtIds
dim(GiorginiENSProtIds)
 
##############################################
# Using the Inparanoid function to find human orthologs in form of human ensembl protein IDs#
##################################################

rawHumanProtIds <- mget(unlist(GiorginiENSProtIds$ensembl_peptide_id) ,hom.Sc.inpHOMSA,ifnotfound=NA)

rawHumanProtIds
class(rawHumanProtIds)
HumanProtIds <- rawHumanProtIds[!is.na(rawHumanProtIds)] ## remove all the NA values from the list
HumanProtIds
length(HumanProtIds)

##########################################################################
## Find the ensembl gene id annd hgnc symbols for your human ensembl peptide id 
## using the getBM function and the human ensembl dataset
#######################################################################

human = useMart(host='dec2014.archive.ensembl.org',biomart = 'ENSEMBL_MART_ENSEMBL', dataset = "hsapiens_gene_ensembl")
Humanorthologs <- getBM(c('ensembl_gene_id', 'hgnc_symbol', 'ensembl_peptide_id', 'entrezgene'), filters='ensembl_peptide_id', values=HumanProtIds, mart=human) # convert Gene Symbol to ensemble gene id and ensembl protein id for your organism
Humanorthologs
dim(Humanorthologs)

## run the line below if need output in text file.
# write.table(Humanorthologs, file="GiorginiHumanOrthologs.txt", sep="\t", col.names = NA) ### export file in text format to the folder.


##############################################################################################
##########END ################################################################################
#############################################################################################

sessionInfo()
# Out:
#   name               description
# 1 chromosome_name    Chromosome name
# 2 start              Gene Start (bp)
# 3 end                Gene End (bp)
# 4 strand             Strand
# 5 chromosomal_region Chromosome Regions (e.g 1:100:10000:-1,1:100000:200000:1)
#     name
# 1   chromosome_name
# 2   start
# 3   end
# 4   strand
# 5   chromosomal_region
# 6   with_tra_tsl
# 7   with_tra_appris_pi
# 8   with_tra_gencode_basic
# 9   with_ec_number
# 10  with_embl
# 11  with_entrezgene
# 12  with_go_go
# 13  with_go_id
# 14  with_goslim_goa
# 15  with_merops
# 16  with_pdb
# 17  with_protein_id
# 18  with_refseq_dna
# 19  with_refseq_mrna
# 20  with_refseq_peptide
# 21  with_sgd_gene
# 22  with_sgd_transcript
# 23  with_uniparc
# 24  with_ox_uniprotswissprot
# 25  with_uniprotsptrembl
# 26  with_ox_uniprotsptrembl
# 27  with_wikigene
# 28  with_affy_yeast_2
# 29  with_affy_yg_s98
# 30  ensembl_gene_id
# ... ...
# 137 with_prosite
# 138 with_profile
# 139 with_tmhmm
# 140 with_tigrfam
# 141 with_superfamily
# 142 with_smart
# 143 with_signalp
# 144 with_low_complexity
# 145 with_pirsf
# 146 with_coil
# 147 with_interpro
# 148 with_protein_feature_pfam
# 149 with_protein_feature_prints
# 150 tigrfam
# 151 gene3d
# 152 superfamily
# 153 smart
# 154 pirsf
# 155 family
# 156 pfam
# 157 hmmpanther
# 158 prints
# 159 profile
# 160 prosite
# 161 interpro
# 162 with_transmembrane_domain
# 163 with_signal_domain
# 164 germ_line_variation_source
# 165 with_validated_snp
# 166 so_parent_name
#     description
# 1   Chromosome name
# 2   Gene Start (bp)
# 3   Gene End (bp)
# 4   Strand
# 5   Chromosome Regions (e.g 1:100:10000:-1,1:100000:200000:1)
# 6   with Transcript Support Level (TSL)
# 7   with APPRIS principal isoform annotation
# 8   with GENCODE basic annotation
# 9   with EC number(s)
# 10  with EMBL ID(s)
# 11  with EntrezGene ID(s)
# 12  with GO ID(s)
# 13  with GO Term Accession(s)
# 14  with GOSlim GOA(s)
# 15  with MEROPS ID(s)
# 16  with PDB ID(s)
# 17  with protein(Genbank) ID(s)
# 18  with RefSeq DNA ID(s)
# 19  with RefSeq mRNA ID(s)
# 20  with RefSeq protein ID(s)
# 21  with SGD gene ID(s)
# 22  with SGD transcript ID(s)
# 23  with UniParc ID(s)
# 24  with UniProtSWISSPROT ID(s)
# 25  with UniProtKB/TrEMBL Accession(s)
# 26  with UniProtSPTREMBL ID(s)
# 27  with WikiGene ID(s)
# 28  with Affymetrix Microarray yeast 2 probeset ID(s)
# 29  with Affymetrix Microarray yg s98 probeset ID(s)
# 30  Ensembl Gene ID(s) [e.g. ENSG00000139618]
# ... ...
# 137 with Protein feature scanprosite ID(s)
# 138 with Protein feature pfscan ID(s)
# 139 with Protein feature tmhmm ID(s)
# 140 with Protein feature tigrfam ID(s)
# 141 with Protein feature superfamily ID(s)
# 142 with Protein feature smart ID(s)
# 143 with Protein feature signalp ID(s)
# 144 with Protein feature seg ID(s)
# 145 with Protein feature pirsf ID(s)
# 146 with Protein feature ncoils ID(s)
# 147 with InterPro ID(s)
# 148 with PFAM ID(s)
# 149 with PRINTS ID(s)
# 150 TIGRfam ID(s) [e.g. TIGR00172]
# 151 Gene3D ID(s) [e.g. G3DSA:2.130.10.10]
# 152 Superfamily ID(s) [e.g. SSF47095]
# 153 SMART ID(s) [e.g. SM00398]
# 154 PIRSF ID(s) [e.g. PIRSF037653]
# 155 Ensembl Protein Family ID(s) [e.g. ENSFM00250000000002]
# 156 PFAM ID(s) [e.g. PF00046]
# 157 HMMPanther ID(s) [e.g. PTHR12369]
# 158 PRINTS ID(s) [e.g. PR00194]
# 159 PROFILE ID(s) [e.g. PS50313]
# 160 PROSITE ID(s) [e.g. PS00028]
# 161 Interpro ID(s) [e.g. IPR007087]
# 162 Transmembrane domains
# 163 Signal domains
# 164 limit to genes with germline variation data sources
# 165 Associated with validated SNPs
# 166 Parent term name
#   name                  description           page
# 1 ensembl_gene_id       Ensembl Gene ID       feature_page
# 2 ensembl_transcript_id Ensembl Transcript ID feature_page
# 3 ensembl_peptide_id    Ensembl Protein ID    feature_page
# 4 ensembl_exon_id       Ensembl Exon ID       feature_page
# 5 description           Description           feature_page
#     name                            description
# 1   ensembl_gene_id                 Ensembl Gene ID
# 2   ensembl_transcript_id           Ensembl Transcript ID
# 3   ensembl_peptide_id              Ensembl Protein ID
# 4   ensembl_exon_id                 Ensembl Exon ID
# 5   description                     Description
# 6   chromosome_name                 Chromosome Name
# 7   start_position                  Gene Start (bp)
# 8   end_position                    Gene End (bp)
# 9   strand                          Strand
# 10  band                            Band
# 11  transcript_start                Transcript Start (bp)
# 12  transcript_end                  Transcript End (bp)
# 13  transcription_start_site        Transcription Start Site (TSS)
# 14  transcript_length               Transcript length
# 15  transcript_tsl                  Transcript Support Level (TSL)
# 16  transcript_gencode_basic        GENCODE basic annotation
# 17  transcript_appris_pi            APPRIS principal isoform annotation
# 18  external_gene_name              Associated Gene Name
# 19  external_gene_source            Associated Gene Source
# 20  external_transcript_name        Associated Transcript Name
# 21  external_transcript_source_name Associated Transcript Source
# 22  transcript_count                Transcript count
# 23  percentage_gc_content           % GC content
# 24  gene_biotype                    Gene type
# 25  transcript_biotype              Transcript type
# 26  source                          Source (gene)
# 27  transcript_source               Source (transcript)
# 28  status                          Status (gene)
# 29  transcript_status               Status (transcript)
# 30  version                         Version (gene)
# ... ...                             ...
# 48  sgd_gene                        SGD Gene
# 49  sgd_transcript                  SGD Transcript
# 50  uniparc                         UniParc
# 51  uniprot_sptrembl                UniProt/TrEMBL Accession
# 52  uniprot_swissprot               UniProt/SwissProt ID
# 53  uniprot_swissprot_accession     UniProt/SwissProt Accession
# 54  wikigene_name                   WikiGene Name
# 55  wikigene_id                     WikiGene ID
# 56  wikigene_description            WikiGene Description
# 57  affy_yeast_2                    Affy yeast 2 probeset
# 58  affy_yg_s98                     Affy yg s98 probeset
# 59  family                          Ensembl Protein Family ID(s)
# 60  family_description              Ensembl Family Description
# 61  pirsf                           PIRSF SuperFamily ID
# 62  superfamily                     Superfamily ID
# 63  smart                           SMART ID
# 64  profile                         PROFILE ID
# 65  prosite                         PROSITE ID
# 66  prints                          PRINTS ID
# 67  pfam                            PFAM ID
# 68  tigrfam                         TIGRFam ID
# 69  gene3d                          Gene3D ID
# 70  hmmpanther                      HMMPanther ID
# 71  interpro                        Interpro ID
# 72  interpro_short_description      Interpro Short Description
# 73  interpro_description            Interpro Description
# 74  low_complexity                  Low complexity
# 75  transmembrane_domain            Transmembrane domain
# 76  signal_domain                   Signal domain
# 77  ncoils                          Ncoils
#     page
# 1   feature_page
# 2   feature_page
# 3   feature_page
# 4   feature_page
# 5   feature_page
# 6   feature_page
# 7   feature_page
# 8   feature_page
# 9   feature_page
# 10  feature_page
# 11  feature_page
# 12  feature_page
# 13  feature_page
# 14  feature_page
# 15  feature_page
# 16  feature_page
# 17  feature_page
# 18  feature_page
# 19  feature_page
# 20  feature_page
# 21  feature_page
# 22  feature_page
# 23  feature_page
# 24  feature_page
# 25  feature_page
# 26  feature_page
# 27  feature_page
# 28  feature_page
# 29  feature_page
# 30  feature_page
# ... ...
# 48  feature_page
# 49  feature_page
# 50  feature_page
# 51  feature_page
# 52  feature_page
# 53  feature_page
# 54  feature_page
# 55  feature_page
# 56  feature_page
# 57  feature_page
# 58  feature_page
# 59  feature_page
# 60  feature_page
# 61  feature_page
# 62  feature_page
# 63  feature_page
# 64  feature_page
# 65  feature_page
# 66  feature_page
# 67  feature_page
# 68  feature_page
# 69  feature_page
# 70  feature_page
# 71  feature_page
# 72  feature_page
# 73  feature_page
# 74  feature_page
# 75  feature_page
# 76  feature_page
# 77  feature_page
# [1] 3
# [1] 22  3
# [1] "data.frame"
#    ensembl_gene_id external_gene_name ensembl_peptide_id
# 1  YBR279W         PAF1               YBR279W
# 2  YDR525W-A       SNA2               YDR525W-A
# 3  YOR198C         BFR1               YOR198C
# 4  YLR278C                            YLR278C
# 5  YBR073W         RDH54              YBR073W
# 6  YJL029C         VPS53              YJL029C
# 7  YOR298C-A       MBF1               YOR298C-A
# 8  YDL117W         CYK3               YDL117W
# 9  YBL098W         BNA4               YBL098W
# 10 YNR049C         MSO1               YNR049C
# 11 YPL139C         UME1               YPL139C
# 12 YMR062C         ARG7               YMR062C
# 13 YLL026W         HSP104             YLL026W
# 14 YBR172C         SMY2               YBR172C
# 15 YDL200C         MGT1               YDL200C
# 16 YBR016W                            YBR016W
# 17 YCL028W         RNQ1               YCL028W
# 18 YMR244C-A                          YMR244C-A
# 19 YCR037C         PHO87              YCR037C
# 20 YDL076C         RXT3               YDL076C
# 21 YBR089C-A       NHP6B              YBR089C-A
# 22 YKL054C         DEF1               YKL054C
#    ensembl_gene_id external_gene_name ensembl_peptide_id
# 1  YBR279W         PAF1               YBR279W
# 2  YDR525W-A       SNA2               YDR525W-A
# 3  YOR198C         BFR1               YOR198C
# 4  YLR278C                            YLR278C
# 5  YBR073W         RDH54              YBR073W
# 6  YJL029C         VPS53              YJL029C
# 7  YOR298C-A       MBF1               YOR298C-A
# 8  YDL117W         CYK3               YDL117W
# 9  YBL098W         BNA4               YBL098W
# 10 YNR049C         MSO1               YNR049C
# 11 YPL139C         UME1               YPL139C
# 12 YMR062C         ARG7               YMR062C
# 13 YLL026W         HSP104             YLL026W
# 14 YBR172C         SMY2               YBR172C
# 15 YDL200C         MGT1               YDL200C
# 16 YBR016W                            YBR016W
# 17 YCL028W         RNQ1               YCL028W
# 18 YMR244C-A                          YMR244C-A
# 19 YCR037C         PHO87              YCR037C
# 20 YDL076C         RXT3               YDL076C
# 21 YBR089C-A       NHP6B              YBR089C-A
# 22 YKL054C         DEF1               YKL054C
# [1] 22  3
# $YBR279W
# [1] "ENSP00000221265"
#
# $`YDR525W-A`
# [1] NA
#
# $YOR198C
# [1] NA
#
# $YLR278C
# [1] NA
#
# $YBR073W
# [1] NA
#
# $YJL029C
# [1] "ENSP00000373692"
#
# $`YOR298C-A`
# [1] "ENSP00000224073"
#
# $YDL117W
# [1] NA
#
# $YBL098W
# [1] "ENSP00000355517"
#
# $YNR049C
# [1] NA
#
# $YPL139C
# [1] NA
#
# $YMR062C
# [1] NA
#
# $YLL026W
# [1] NA
#
# $YBR172C
# [1] "ENSP00000275732"
#
# $YDL200C
# [1] NA
#
# $YBR016W
# [1] NA
#
# $YCL028W
# [1] NA
#
# $`YMR244C-A`
# [1] NA
#
# $YCR037C
# [1] NA
#
# $YDL076C
# [1] NA
#
# $`YBR089C-A`
# [1] NA
#
# $YKL054C
# [1] NA
# [1] "list"
# $YBR279W
# [1] "ENSP00000221265"
#
# $YJL029C
# [1] "ENSP00000373692"
#
# $`YOR298C-A`
# [1] "ENSP00000224073"
#
# $YBL098W
# [1] "ENSP00000355517"
#
# $YBR172C
# [1] "ENSP00000275732"
# [1] 5
#   ensembl_gene_id hgnc_symbol ensembl_peptide_id entrezgene
# 1 ENSG00000006712 PAF1        ENSP00000221265    54623
# 2 ENSG00000107223 EDF1        ENSP00000224073     8721
# 3 ENSG00000146830 GIGYF1      ENSP00000275732    64599
# 4 ENSG00000117009 KMO         ENSP00000355517     8564
# 5 ENSG00000141252 VPS53       ENSP00000373692    55275
# [1] 5 4
# R version 3.3.1 (2016-06-21)
# Platform: x86_64-w64-mingw32/x64 (64-bit)
# Running under: Windows 10 x64 (build 14393)
#
# locale:
# [1] LC_COLLATE=English_United States.1252
# [2] LC_CTYPE=English_United States.1252
# [3] LC_MONETARY=English_United States.1252
# [4] LC_NUMERIC=C
# [5] LC_TIME=English_United States.1252
#
# attached base packages:
# [1] parallel  stats4    stats     graphics  grDevices utils     datasets
# [8] methods   base
#
# other attached packages:
# [1] plyr_1.8.4           biomaRt_2.30.0       hom.Sc.inp.db_3.1.2
# [4] AnnotationDbi_1.36.2 IRanges_2.8.2        S4Vectors_0.12.2
# [7] Biobase_2.34.0       BiocGenerics_0.20.0  BiocInstaller_1.24.0
#
# loaded via a namespace (and not attached):
#  [1] Rcpp_0.12.10        magrittr_1.5        uuid_0.1-2
#  [4] R6_2.2.0            stringr_1.2.0       tools_3.3.1
#  [7] DBI_0.6-1           digest_0.6.12       crayon_1.3.2
# [10] IRdisplay_0.4.4     repr_0.12.0         bitops_1.0-6
# [13] RCurl_1.95-4.8      IRkernel_0.8.6.9000 memoise_1.0.0
# [16] evaluate_0.10       RSQLite_1.1-2       pbdZMQ_0.2-5
# [19] stringi_1.1.5       XML_3.98-1.6        jsonlite_1.4

# %% [markdown]
# ### Chatterjee et al 2013

# %%
path <- "C:/Users/Sonali/Box Sync/Huntington Interactome/MutantHTT_Interactors/Yeast/MutantHttSuppressors_green"
setwd(path)

#####################################################
### Get the required libararies
#####################################################
library("AnnotationDbi")
library("hom.Sc.inp.db")
library("biomaRt")
library ("plyr")

########################################
###Biomart package installation####
#######################################
# source("http://bioconductor.org/biocLite.R")
# biocLite("biomaRt")
# 
# #########################################
# ##To view documentation for the version of this package ###
# ############################################################
# browseVignettes("biomaRt")
# 
# ###################################################
# ### code chunk number 2: biomaRt
# ###################################################
# library("biomaRt")
# listMarts()
# 
# 
# 
# ###################################################
# ### code chunk number 4: listDatasets
# ###################################################
# listDatasets(ensembl)

#############################################################
### Read the file containing the gene symbols of the organism
###############################################################

yeastEGIds <- read.table(file= "R_Input_Chatterjee_etal2013.txt", sep = "\t", header = TRUE)

# convert your Gene Symbols to ensemble gene id and ensembl protein id for your organism

yeast = useMart(host='dec2014.archive.ensembl.org',biomart = 'ENSEMBL_MART_ENSEMBL', dataset = "scerevisiae_gene_ensembl") ### specify the dataset to use 

###################################################
### filters for the yeast dataset
###################################################
filters = listFilters(yeast)
filters[1:5,]
listFilters(yeast)

###################################################
### attributes for yeast dataset
###################################################
attributes = listAttributes(yeast)

attributes[1:5,]
listAttributes(yeast, page="feature_page")


########################################
## Get the attributes for yeast dataset 
#######################################


rawChatterjeeENSProtIds <- getBM(c('ensembl_gene_id', 'external_gene_name', 'ensembl_peptide_id'), filters='wikigene_name', 'external_gene_name', values= yeastEGIds$ConfirmedSuppressorGenes, mart=yeast) # convert Gene Symbol to ensemble gene id and ensembl protein id for your organism
length (rawChatterjeeENSProtIds)
dim (rawChatterjeeENSProtIds)
class(rawChatterjeeENSProtIds)
rawChatterjeeENSProtIds


#########################################
# remove duplicate values from the ensembl protein id column
#######################################

ChatterjeeENSProtIds <- rawChatterjeeENSProtIds[!duplicated(rawChatterjeeENSProtIds[,3]),]
ChatterjeeENSProtIds
dim(ChatterjeeENSProtIds)
 
##############################################
# Using the Inparanoid function to find human orthologs in form of human ensembl protein IDs#
##################################################

rawHumanProtIds <- mget(unlist(ChatterjeeENSProtIds$ensembl_peptide_id) ,hom.Sc.inpHOMSA,ifnotfound=NA)

rawHumanProtIds
class(rawHumanProtIds)
HumanProtIds <- rawHumanProtIds[!is.na(rawHumanProtIds)] ## remove all the NA values from the list
HumanProtIds
length(HumanProtIds)

##########################################################################
## Find the ensembl gene id annd hgnc symbols for your human ensembl peptide id 
## using the getBM function and the human ensembl dataset
#######################################################################

human = useMart(host='dec2014.archive.ensembl.org',biomart = 'ENSEMBL_MART_ENSEMBL', dataset = "hsapiens_gene_ensembl")
Humanorthologs <- getBM(c('ensembl_gene_id', 'hgnc_symbol', 'ensembl_peptide_id', 'entrezgene'), filters='ensembl_peptide_id', values=HumanProtIds, mart=human) # convert Gene Symbol to ensemble gene id and ensembl protein id for your organism
Humanorthologs
dim(Humanorthologs)

## run the line below if need output in text file.
#write.table(Humanorthologs, file="ChatterjeeHumanOrthologs.txt", sep="\t", col.names = NA) ### export file in text format to the folder.


##############################################################################################
##########END ################################################################################
#############################################################################################

sessionInfo()
# Out:
#   name               description
# 1 chromosome_name    Chromosome name
# 2 start              Gene Start (bp)
# 3 end                Gene End (bp)
# 4 strand             Strand
# 5 chromosomal_region Chromosome Regions (e.g 1:100:10000:-1,1:100000:200000:1)
#     name
# 1   chromosome_name
# 2   start
# 3   end
# 4   strand
# 5   chromosomal_region
# 6   with_tra_tsl
# 7   with_tra_appris_pi
# 8   with_tra_gencode_basic
# 9   with_ec_number
# 10  with_embl
# 11  with_entrezgene
# 12  with_go_go
# 13  with_go_id
# 14  with_goslim_goa
# 15  with_merops
# 16  with_pdb
# 17  with_protein_id
# 18  with_refseq_dna
# 19  with_refseq_mrna
# 20  with_refseq_peptide
# 21  with_sgd_gene
# 22  with_sgd_transcript
# 23  with_uniparc
# 24  with_ox_uniprotswissprot
# 25  with_uniprotsptrembl
# 26  with_ox_uniprotsptrembl
# 27  with_wikigene
# 28  with_affy_yeast_2
# 29  with_affy_yg_s98
# 30  ensembl_gene_id
# ... ...
# 137 with_prosite
# 138 with_profile
# 139 with_tmhmm
# 140 with_tigrfam
# 141 with_superfamily
# 142 with_smart
# 143 with_signalp
# 144 with_low_complexity
# 145 with_pirsf
# 146 with_coil
# 147 with_interpro
# 148 with_protein_feature_pfam
# 149 with_protein_feature_prints
# 150 tigrfam
# 151 gene3d
# 152 superfamily
# 153 smart
# 154 pirsf
# 155 family
# 156 pfam
# 157 hmmpanther
# 158 prints
# 159 profile
# 160 prosite
# 161 interpro
# 162 with_transmembrane_domain
# 163 with_signal_domain
# 164 germ_line_variation_source
# 165 with_validated_snp
# 166 so_parent_name
#     description
# 1   Chromosome name
# 2   Gene Start (bp)
# 3   Gene End (bp)
# 4   Strand
# 5   Chromosome Regions (e.g 1:100:10000:-1,1:100000:200000:1)
# 6   with Transcript Support Level (TSL)
# 7   with APPRIS principal isoform annotation
# 8   with GENCODE basic annotation
# 9   with EC number(s)
# 10  with EMBL ID(s)
# 11  with EntrezGene ID(s)
# 12  with GO ID(s)
# 13  with GO Term Accession(s)
# 14  with GOSlim GOA(s)
# 15  with MEROPS ID(s)
# 16  with PDB ID(s)
# 17  with protein(Genbank) ID(s)
# 18  with RefSeq DNA ID(s)
# 19  with RefSeq mRNA ID(s)
# 20  with RefSeq protein ID(s)
# 21  with SGD gene ID(s)
# 22  with SGD transcript ID(s)
# 23  with UniParc ID(s)
# 24  with UniProtSWISSPROT ID(s)
# 25  with UniProtKB/TrEMBL Accession(s)
# 26  with UniProtSPTREMBL ID(s)
# 27  with WikiGene ID(s)
# 28  with Affymetrix Microarray yeast 2 probeset ID(s)
# 29  with Affymetrix Microarray yg s98 probeset ID(s)
# 30  Ensembl Gene ID(s) [e.g. ENSG00000139618]
# ... ...
# 137 with Protein feature scanprosite ID(s)
# 138 with Protein feature pfscan ID(s)
# 139 with Protein feature tmhmm ID(s)
# 140 with Protein feature tigrfam ID(s)
# 141 with Protein feature superfamily ID(s)
# 142 with Protein feature smart ID(s)
# 143 with Protein feature signalp ID(s)
# 144 with Protein feature seg ID(s)
# 145 with Protein feature pirsf ID(s)
# 146 with Protein feature ncoils ID(s)
# 147 with InterPro ID(s)
# 148 with PFAM ID(s)
# 149 with PRINTS ID(s)
# 150 TIGRfam ID(s) [e.g. TIGR00172]
# 151 Gene3D ID(s) [e.g. G3DSA:2.130.10.10]
# 152 Superfamily ID(s) [e.g. SSF47095]
# 153 SMART ID(s) [e.g. SM00398]
# 154 PIRSF ID(s) [e.g. PIRSF037653]
# 155 Ensembl Protein Family ID(s) [e.g. ENSFM00250000000002]
# 156 PFAM ID(s) [e.g. PF00046]
# 157 HMMPanther ID(s) [e.g. PTHR12369]
# 158 PRINTS ID(s) [e.g. PR00194]
# 159 PROFILE ID(s) [e.g. PS50313]
# 160 PROSITE ID(s) [e.g. PS00028]
# 161 Interpro ID(s) [e.g. IPR007087]
# 162 Transmembrane domains
# 163 Signal domains
# 164 limit to genes with germline variation data sources
# 165 Associated with validated SNPs
# 166 Parent term name
#   name                  description           page
# 1 ensembl_gene_id       Ensembl Gene ID       feature_page
# 2 ensembl_transcript_id Ensembl Transcript ID feature_page
# 3 ensembl_peptide_id    Ensembl Protein ID    feature_page
# 4 ensembl_exon_id       Ensembl Exon ID       feature_page
# 5 description           Description           feature_page
#     name                            description
# 1   ensembl_gene_id                 Ensembl Gene ID
# 2   ensembl_transcript_id           Ensembl Transcript ID
# 3   ensembl_peptide_id              Ensembl Protein ID
# 4   ensembl_exon_id                 Ensembl Exon ID
# 5   description                     Description
# 6   chromosome_name                 Chromosome Name
# 7   start_position                  Gene Start (bp)
# 8   end_position                    Gene End (bp)
# 9   strand                          Strand
# 10  band                            Band
# 11  transcript_start                Transcript Start (bp)
# 12  transcript_end                  Transcript End (bp)
# 13  transcription_start_site        Transcription Start Site (TSS)
# 14  transcript_length               Transcript length
# 15  transcript_tsl                  Transcript Support Level (TSL)
# 16  transcript_gencode_basic        GENCODE basic annotation
# 17  transcript_appris_pi            APPRIS principal isoform annotation
# 18  external_gene_name              Associated Gene Name
# 19  external_gene_source            Associated Gene Source
# 20  external_transcript_name        Associated Transcript Name
# 21  external_transcript_source_name Associated Transcript Source
# 22  transcript_count                Transcript count
# 23  percentage_gc_content           % GC content
# 24  gene_biotype                    Gene type
# 25  transcript_biotype              Transcript type
# 26  source                          Source (gene)
# 27  transcript_source               Source (transcript)
# 28  status                          Status (gene)
# 29  transcript_status               Status (transcript)
# 30  version                         Version (gene)
# ... ...                             ...
# 48  sgd_gene                        SGD Gene
# 49  sgd_transcript                  SGD Transcript
# 50  uniparc                         UniParc
# 51  uniprot_sptrembl                UniProt/TrEMBL Accession
# 52  uniprot_swissprot               UniProt/SwissProt ID
# 53  uniprot_swissprot_accession     UniProt/SwissProt Accession
# 54  wikigene_name                   WikiGene Name
# 55  wikigene_id                     WikiGene ID
# 56  wikigene_description            WikiGene Description
# 57  affy_yeast_2                    Affy yeast 2 probeset
# 58  affy_yg_s98                     Affy yg s98 probeset
# 59  family                          Ensembl Protein Family ID(s)
# 60  family_description              Ensembl Family Description
# 61  pirsf                           PIRSF SuperFamily ID
# 62  superfamily                     Superfamily ID
# 63  smart                           SMART ID
# 64  profile                         PROFILE ID
# 65  prosite                         PROSITE ID
# 66  prints                          PRINTS ID
# 67  pfam                            PFAM ID
# 68  tigrfam                         TIGRFam ID
# 69  gene3d                          Gene3D ID
# 70  hmmpanther                      HMMPanther ID
# 71  interpro                        Interpro ID
# 72  interpro_short_description      Interpro Short Description
# 73  interpro_description            Interpro Description
# 74  low_complexity                  Low complexity
# 75  transmembrane_domain            Transmembrane domain
# 76  signal_domain                   Signal domain
# 77  ncoils                          Ncoils
#     page
# 1   feature_page
# 2   feature_page
# 3   feature_page
# 4   feature_page
# 5   feature_page
# 6   feature_page
# 7   feature_page
# 8   feature_page
# 9   feature_page
# 10  feature_page
# 11  feature_page
# 12  feature_page
# 13  feature_page
# 14  feature_page
# 15  feature_page
# 16  feature_page
# 17  feature_page
# 18  feature_page
# 19  feature_page
# 20  feature_page
# 21  feature_page
# 22  feature_page
# 23  feature_page
# 24  feature_page
# 25  feature_page
# 26  feature_page
# 27  feature_page
# 28  feature_page
# 29  feature_page
# 30  feature_page
# ... ...
# 48  feature_page
# 49  feature_page
# 50  feature_page
# 51  feature_page
# 52  feature_page
# 53  feature_page
# 54  feature_page
# 55  feature_page
# 56  feature_page
# 57  feature_page
# 58  feature_page
# 59  feature_page
# 60  feature_page
# 61  feature_page
# 62  feature_page
# 63  feature_page
# 64  feature_page
# 65  feature_page
# 66  feature_page
# 67  feature_page
# 68  feature_page
# 69  feature_page
# 70  feature_page
# 71  feature_page
# 72  feature_page
# 73  feature_page
# 74  feature_page
# 75  feature_page
# 76  feature_page
# 77  feature_page
# [1] 3
# [1] 43  3
# [1] "data.frame"
#    ensembl_gene_id external_gene_name ensembl_peptide_id
# 1  YJR094W-A       RPL43B             YJR094W-A
# 2  YNL069C         RPL16B             YNL069C
# 3  YPL143W         RPL33A             YPL143W
# 4  YDL082W         RPL13A             YDL082W
# 5  YDL136W         RPL35B             YDL136W
# 6  YMR194W         RPL36A             YMR194W
# 7  YLR441C         RPS1A              YLR441C
# 8  YBR084C-A       RPL19A             YBR084C-A
# 9  YDR418W         RPL12B             YDR418W
# 10 YML026C         RPS18B             YML026C
# 11 YIL069C         RPS24B             YIL069C
# 12 YDR405W         MRP20              YDR405W
# 13 YLR388W         RPS29A             YLR388W
# 14 YDR471W         RPL27B             YDR471W
# 15 YDR450W         RPS18A             YDR450W
# 16 YER074W         RPS24A             YER074W
# 17 YLR312W-A       MRPL15             YLR312W-A
# 18 YNL306W         MRPS18             YNL306W
# 19 YJL190C         RPS22A             YJL190C
# 20 YOR234C         RPL33B             YOR234C
# 21 YBR181C         RPS6B              YBR181C
# 22 YPL249C-A       RPL36B             YPL249C-A
# 23 YPL090C         RPS6A              YPL090C
# 24 YLR333C         RPS25B             YLR333C
# 25 YMR143W         RPS16A             YMR143W
# 26 YEL054C         RPL12A             YEL054C
# 27 YOL040C         RPS15              YOL040C
# 28 YKL180W         RPL17A             YKL180W
# 29 YEL050C         RML2               YEL050C
# 30 YBL027W         RPL19B             YBL027W
# 31 YDL191W         RPL35A             YDL191W
# 32 YLR264W         RPS28B             YLR264W
# 33 YMR142C         RPL13B             YMR142C
# 34 YJR101W         RSM26              YJR101W
# 35 YPR043W         RPL43A             YPR043W
# 36 YLR340W         RPP0               YLR340W
# 37 YHL001W         RPL14B             YHL001W
# 38 YDL083C         RPS16B             YDL083C
# 39 YBR189W         RPS9B              YBR189W
# 40 YOL127W         RPL25              YOL127W
# 41 YHR147C         MRPL6              YHR147C
# 42 YGL031C         RPL24A             YGL031C
# 43 YNL302C         RPS19B             YNL302C
#    ensembl_gene_id external_gene_name ensembl_peptide_id
# 1  YJR094W-A       RPL43B             YJR094W-A
# 2  YNL069C         RPL16B             YNL069C
# 3  YPL143W         RPL33A             YPL143W
# 4  YDL082W         RPL13A             YDL082W
# 5  YDL136W         RPL35B             YDL136W
# 6  YMR194W         RPL36A             YMR194W
# 7  YLR441C         RPS1A              YLR441C
# 8  YBR084C-A       RPL19A             YBR084C-A
# 9  YDR418W         RPL12B             YDR418W
# 10 YML026C         RPS18B             YML026C
# 11 YIL069C         RPS24B             YIL069C
# 12 YDR405W         MRP20              YDR405W
# 13 YLR388W         RPS29A             YLR388W
# 14 YDR471W         RPL27B             YDR471W
# 15 YDR450W         RPS18A             YDR450W
# 16 YER074W         RPS24A             YER074W
# 17 YLR312W-A       MRPL15             YLR312W-A
# 18 YNL306W         MRPS18             YNL306W
# 19 YJL190C         RPS22A             YJL190C
# 20 YOR234C         RPL33B             YOR234C
# 21 YBR181C         RPS6B              YBR181C
# 22 YPL249C-A       RPL36B             YPL249C-A
# 23 YPL090C         RPS6A              YPL090C
# 24 YLR333C         RPS25B             YLR333C
# 25 YMR143W         RPS16A             YMR143W
# 26 YEL054C         RPL12A             YEL054C
# 27 YOL040C         RPS15              YOL040C
# 28 YKL180W         RPL17A             YKL180W
# 29 YEL050C         RML2               YEL050C
# 30 YBL027W         RPL19B             YBL027W
# 31 YDL191W         RPL35A             YDL191W
# 32 YLR264W         RPS28B             YLR264W
# 33 YMR142C         RPL13B             YMR142C
# 34 YJR101W         RSM26              YJR101W
# 35 YPR043W         RPL43A             YPR043W
# 36 YLR340W         RPP0               YLR340W
# 37 YHL001W         RPL14B             YHL001W
# 38 YDL083C         RPS16B             YDL083C
# 39 YBR189W         RPS9B              YBR189W
# 40 YOL127W         RPL25              YOL127W
# 41 YHR147C         MRPL6              YHR147C
# 42 YGL031C         RPL24A             YGL031C
# 43 YNL302C         RPS19B             YNL302C
# [1] 43  3
# $`YJR094W-A`
# [1] "ENSP00000352709"
#
# $YNL069C
# [1] NA
#
# $YPL143W
# [1] NA
#
# $YDL082W
# [1] NA
#
# $YDL136W
# [1] "ENSP00000259469"
#
# $YMR194W
# [1] NA
#
# $YLR441C
# [1] NA
#
# $`YBR084C-A`
# [1] "ENSP00000225430"
#
# $YDR418W
# [1] "ENSP00000354739"
#
# $YML026C
# [1] "ENSP00000211372" "ENSP00000363762" "ENSP00000372554"
#
# $YIL069C
# [1] "ENSP00000361435"
#
# $YDR405W
# [1] NA
#
# $YLR388W
# [1] "ENSP00000379339"
#
# $YDR471W
# [1] "ENSP00000253788"
#
# $YDR450W
# [1] "ENSP00000211372" "ENSP00000363762" "ENSP00000372554"
#
# $YER074W
# [1] "ENSP00000361435"
#
# $`YLR312W-A`
# [1] NA
#
# $YNL306W
# [1] NA
#
# $YJL190C
# [1] "ENSP00000318646"
#
# $YOR234C
# [1] "ENSP00000330165"
#
# $YBR181C
# [1] "ENSP00000369757"
#
# $`YPL249C-A`
# [1] "ENSP00000252543"
#
# $YPL090C
# [1] "ENSP00000369757"
#
# $YLR333C
# [1] NA
#
# $YMR143W
# [1] NA
#
# $YEL054C
# [1] "ENSP00000354739"
#
# $YOL040C
# [1] "ENSP00000233609"
#
# $YKL180W
# [1] "ENSP00000386061" "ENSP00000375160"
#
# $YEL050C
# [1] "ENSP00000373404"
#
# $YBL027W
# [1] "ENSP00000225430"
#
# $YDL191W
# [1] "ENSP00000259469"
#
# $YLR264W
# [1] NA
#
# $YMR142C
# [1] "ENSP00000307889"
#
# $YJR101W
# [1] NA
#
# $YPR043W
# [1] "ENSP00000352709"
#
# $YLR340W
# [1] "ENSP00000339027"
#
# $YHL001W
# [1] "ENSP00000350479"
#
# $YDL083C
# [1] NA
#
# $YBR189W
# [1] "ENSP00000302896"
#
# $YOL127W
# [1] "ENSP00000378396"
#
# $YHR147C
# [1] NA
#
# $YGL031C
# [1] "ENSP00000377640"
#
# $YNL302C
# [1] NA
# [1] "list"
# $`YJR094W-A`
# [1] "ENSP00000352709"
#
# $YDL136W
# [1] "ENSP00000259469"
#
# $`YBR084C-A`
# [1] "ENSP00000225430"
#
# $YDR418W
# [1] "ENSP00000354739"
#
# $YML026C
# [1] "ENSP00000211372" "ENSP00000363762" "ENSP00000372554"
#
# $YIL069C
# [1] "ENSP00000361435"
#
# $YLR388W
# [1] "ENSP00000379339"
#
# $YDR471W
# [1] "ENSP00000253788"
#
# $YDR450W
# [1] "ENSP00000211372" "ENSP00000363762" "ENSP00000372554"
#
# $YER074W
# [1] "ENSP00000361435"
#
# $YJL190C
# [1] "ENSP00000318646"
#
# $YOR234C
# [1] "ENSP00000330165"
#
# $YBR181C
# [1] "ENSP00000369757"
#
# $`YPL249C-A`
# [1] "ENSP00000252543"
#
# $YPL090C
# [1] "ENSP00000369757"
#
# $YEL054C
# [1] "ENSP00000354739"
#
# $YOL040C
# [1] "ENSP00000233609"
#
# $YKL180W
# [1] "ENSP00000386061" "ENSP00000375160"
#
# $YEL050C
# [1] "ENSP00000373404"
#
# $YBL027W
# [1] "ENSP00000225430"
#
# $YDL191W
# [1] "ENSP00000259469"
#
# $YMR142C
# [1] "ENSP00000307889"
#
# $YPR043W
# [1] "ENSP00000352709"
#
# $YLR340W
# [1] "ENSP00000339027"
#
# $YHL001W
# [1] "ENSP00000350479"
#
# $YBR189W
# [1] "ENSP00000302896"
#
# $YOL127W
# [1] "ENSP00000378396"
#
# $YGL031C
# [1] "ENSP00000377640"
# [1] 28
#    ensembl_gene_id hgnc_symbol ensembl_peptide_id entrezgene
# 1  ENSG00000096150 RPS18       ENSP00000211372         6222
# 2  ENSG00000108298 RPL19       ENSP00000225430         6143
# 3  ENSG00000130255 RPL36       ENSP00000252543        25873
# 4  ENSG00000131469 RPL27       ENSP00000253788         6155
# 5  ENSG00000136942 RPL35       ENSP00000259469        11224
# 6  ENSG00000170889 RPS9        ENSP00000302896         6203
# 7  ENSG00000167526 RPL13       ENSP00000307889         6137
# 8  ENSG00000167526 RPL13       ENSP00000307889       606500
# 9  ENSG00000134419 RPS15A      ENSP00000318646         6210
# 10 ENSG00000089157 RPLP0       ENSP00000339027         6175
# 11 ENSG00000197958 RPL12       ENSP00000354739         6136
# 12 ENSG00000138326 RPS24       ENSP00000361435         6229
# 13 ENSG00000137154 RPS6        ENSP00000369757         6194
# 14 ENSG00000112651 MRPL2       ENSP00000373404        51069
# 15 ENSG00000114391 RPL24       ENSP00000377640         6152
# 16 ENSG00000198242 RPL23A      ENSP00000378396         6147
# 17 ENSG00000198242 RPL23A      ENSP00000378396        26809
# 18 ENSG00000213741 RPS29       ENSP00000379339         6235
# 19 ENSG00000213741 RPS29       ENSP00000379339    100288910
# [1] 19  4
# R version 3.3.1 (2016-06-21)
# Platform: x86_64-w64-mingw32/x64 (64-bit)
# Running under: Windows 10 x64 (build 14393)
#
# locale:
# [1] LC_COLLATE=English_United States.1252
# [2] LC_CTYPE=English_United States.1252
# [3] LC_MONETARY=English_United States.1252
# [4] LC_NUMERIC=C
# [5] LC_TIME=English_United States.1252
#
# attached base packages:
# [1] parallel  stats4    stats     graphics  grDevices utils     datasets
# [8] methods   base
#
# other attached packages:
# [1] plyr_1.8.4           biomaRt_2.30.0       hom.Sc.inp.db_3.1.2
# [4] AnnotationDbi_1.36.2 IRanges_2.8.2        S4Vectors_0.12.2
# [7] Biobase_2.34.0       BiocGenerics_0.20.0  BiocInstaller_1.24.0
#
# loaded via a namespace (and not attached):
#  [1] Rcpp_0.12.10        magrittr_1.5        uuid_0.1-2
#  [4] R6_2.2.0            stringr_1.2.0       tools_3.3.1
#  [7] DBI_0.6-1           digest_0.6.12       crayon_1.3.2
# [10] IRdisplay_0.4.4     repr_0.12.0         bitops_1.0-6
# [13] RCurl_1.95-4.8      IRkernel_0.8.6.9000 memoise_1.0.0
# [16] evaluate_0.10       RSQLite_1.1-2       pbdZMQ_0.2-5
# [19] stringi_1.1.5       XML_3.98-1.6        jsonlite_1.4

# %% [markdown]
# #### Willingham etal_2003

# %%
path <- "C:/Users/Sonali/Box Sync/Huntington Interactome/MutantHTT_Interactors/Yeast/MutantHttEnhancers_red"
setwd(path)

#####################################################
### Get the required libararies
#####################################################
library("AnnotationDbi")
library("hom.Sc.inp.db")
library("biomaRt")
library ("plyr") #### just in case.

########################################
###Biomart package installation####
#######################################
# source("http://bioconductor.org/biocLite.R")
# biocLite("biomaRt")
# 
# #########################################
# ##To view documentation for the version of this package ###
# ############################################################
# browseVignettes("biomaRt")
# 
# ###################################################
# ### code chunk number 2: biomaRt
# ###################################################
# library("biomaRt")
# listMarts()
# 
# 
# 
# ###################################################
# ### code chunk number 4: listDatasets
# ###################################################
# listDatasets(ensembl)

#############################################################
### Read the file containing the gene symbols of the organism
###############################################################

yeastEGIds <- read.table(file= "R_Input_Willingham_etal2003.txt", sep = "\t", header = TRUE)

# convert your Gene Symbols to ensemble gene id and ensembl protein id for your organism

yeast = useMart(host='dec2014.archive.ensembl.org',biomart = 'ENSEMBL_MART_ENSEMBL', dataset = "scerevisiae_gene_ensembl") ### specify the dataset to use 

###################################################
### filters for the yeast dataset
###################################################
filters = listFilters(yeast)
filters[1:5,]
listFilters(yeast)

###################################################
### attributes for yeast dataset
###################################################
attributes = listAttributes(yeast)

attributes[1:5,]
listAttributes(yeast, page="feature_page")


########################################
## Get the attributes for yeast dataset 
#######################################


rawWillinghamENSProtIds <- getBM(c('ensembl_gene_id', 'external_gene_name', 'ensembl_peptide_id'), filters='wikigene_name', 'external_gene_name', values= yeastEGIds$HttEnhancergenes, mart=yeast) # convert Gene Symbol to ensemble gene id and ensembl protein id for your organism
length (rawWillinghamENSProtIds)
dim (rawWillinghamENSProtIds)
class(rawWillinghamENSProtIds)
rawWillinghamENSProtIds


#########################################
# remove duplicate values from the ensembl protein id column
#######################################

WillinghamENSProtIds <- rawWillinghamENSProtIds[!duplicated(rawWillinghamENSProtIds[,3]),]
WillinghamENSProtIds
dim(WillinghamENSProtIds)

##############################################
# Using the Inparanoid function to find human orthologs in form of human ensembl protein IDs#
##################################################

rawHumanProtIds <- mget(unlist(WillinghamENSProtIds$ensembl_peptide_id) ,hom.Sc.inpHOMSA,ifnotfound=NA)

rawHumanProtIds
class(rawHumanProtIds)
HumanProtIds <- rawHumanProtIds[!is.na(rawHumanProtIds)] ## remove all the NA values from the list
HumanProtIds
length(HumanProtIds)

##########################################################################
## Find the ensembl gene id annd hgnc symbols for your human ensembl peptide id 
## using the getBM function and the human ensembl dataset
#######################################################################

human = useMart(host='dec2014.archive.ensembl.org',biomart = 'ENSEMBL_MART_ENSEMBL', dataset = "hsapiens_gene_ensembl")
Humanorthologs <- getBM(c('ensembl_gene_id', 'hgnc_symbol', 'ensembl_peptide_id', 'entrezgene'), filters='ensembl_peptide_id', values=HumanProtIds, mart=human) # convert Gene Symbol to ensemble gene id and ensembl protein id for your organism
Humanorthologs
dim(Humanorthologs)

## run the line below if need output in text file.
#write.table(Humanorthologs, file="WillinghamHumanOrthologs.txt", sep="\t", col.names = NA) ### export file in text format to the folder.


##############################################################################################
##########END ################################################################################
#############################################################################################

sessionInfo()
# Out:
#   name               description
# 1 chromosome_name    Chromosome name
# 2 start              Gene Start (bp)
# 3 end                Gene End (bp)
# 4 strand             Strand
# 5 chromosomal_region Chromosome Regions (e.g 1:100:10000:-1,1:100000:200000:1)
#     name
# 1   chromosome_name
# 2   start
# 3   end
# 4   strand
# 5   chromosomal_region
# 6   with_tra_tsl
# 7   with_tra_appris_pi
# 8   with_tra_gencode_basic
# 9   with_ec_number
# 10  with_embl
# 11  with_entrezgene
# 12  with_go_go
# 13  with_go_id
# 14  with_goslim_goa
# 15  with_merops
# 16  with_pdb
# 17  with_protein_id
# 18  with_refseq_dna
# 19  with_refseq_mrna
# 20  with_refseq_peptide
# 21  with_sgd_gene
# 22  with_sgd_transcript
# 23  with_uniparc
# 24  with_ox_uniprotswissprot
# 25  with_uniprotsptrembl
# 26  with_ox_uniprotsptrembl
# 27  with_wikigene
# 28  with_affy_yeast_2
# 29  with_affy_yg_s98
# 30  ensembl_gene_id
# ... ...
# 137 with_prosite
# 138 with_profile
# 139 with_tmhmm
# 140 with_tigrfam
# 141 with_superfamily
# 142 with_smart
# 143 with_signalp
# 144 with_low_complexity
# 145 with_pirsf
# 146 with_coil
# 147 with_interpro
# 148 with_protein_feature_pfam
# 149 with_protein_feature_prints
# 150 tigrfam
# 151 gene3d
# 152 superfamily
# 153 smart
# 154 pirsf
# 155 family
# 156 pfam
# 157 hmmpanther
# 158 prints
# 159 profile
# 160 prosite
# 161 interpro
# 162 with_transmembrane_domain
# 163 with_signal_domain
# 164 germ_line_variation_source
# 165 with_validated_snp
# 166 so_parent_name
#     description
# 1   Chromosome name
# 2   Gene Start (bp)
# 3   Gene End (bp)
# 4   Strand
# 5   Chromosome Regions (e.g 1:100:10000:-1,1:100000:200000:1)
# 6   with Transcript Support Level (TSL)
# 7   with APPRIS principal isoform annotation
# 8   with GENCODE basic annotation
# 9   with EC number(s)
# 10  with EMBL ID(s)
# 11  with EntrezGene ID(s)
# 12  with GO ID(s)
# 13  with GO Term Accession(s)
# 14  with GOSlim GOA(s)
# 15  with MEROPS ID(s)
# 16  with PDB ID(s)
# 17  with protein(Genbank) ID(s)
# 18  with RefSeq DNA ID(s)
# 19  with RefSeq mRNA ID(s)
# 20  with RefSeq protein ID(s)
# 21  with SGD gene ID(s)
# 22  with SGD transcript ID(s)
# 23  with UniParc ID(s)
# 24  with UniProtSWISSPROT ID(s)
# 25  with UniProtKB/TrEMBL Accession(s)
# 26  with UniProtSPTREMBL ID(s)
# 27  with WikiGene ID(s)
# 28  with Affymetrix Microarray yeast 2 probeset ID(s)
# 29  with Affymetrix Microarray yg s98 probeset ID(s)
# 30  Ensembl Gene ID(s) [e.g. ENSG00000139618]
# ... ...
# 137 with Protein feature scanprosite ID(s)
# 138 with Protein feature pfscan ID(s)
# 139 with Protein feature tmhmm ID(s)
# 140 with Protein feature tigrfam ID(s)
# 141 with Protein feature superfamily ID(s)
# 142 with Protein feature smart ID(s)
# 143 with Protein feature signalp ID(s)
# 144 with Protein feature seg ID(s)
# 145 with Protein feature pirsf ID(s)
# 146 with Protein feature ncoils ID(s)
# 147 with InterPro ID(s)
# 148 with PFAM ID(s)
# 149 with PRINTS ID(s)
# 150 TIGRfam ID(s) [e.g. TIGR00172]
# 151 Gene3D ID(s) [e.g. G3DSA:2.130.10.10]
# 152 Superfamily ID(s) [e.g. SSF47095]
# 153 SMART ID(s) [e.g. SM00398]
# 154 PIRSF ID(s) [e.g. PIRSF037653]
# 155 Ensembl Protein Family ID(s) [e.g. ENSFM00250000000002]
# 156 PFAM ID(s) [e.g. PF00046]
# 157 HMMPanther ID(s) [e.g. PTHR12369]
# 158 PRINTS ID(s) [e.g. PR00194]
# 159 PROFILE ID(s) [e.g. PS50313]
# 160 PROSITE ID(s) [e.g. PS00028]
# 161 Interpro ID(s) [e.g. IPR007087]
# 162 Transmembrane domains
# 163 Signal domains
# 164 limit to genes with germline variation data sources
# 165 Associated with validated SNPs
# 166 Parent term name
#   name                  description           page
# 1 ensembl_gene_id       Ensembl Gene ID       feature_page
# 2 ensembl_transcript_id Ensembl Transcript ID feature_page
# 3 ensembl_peptide_id    Ensembl Protein ID    feature_page
# 4 ensembl_exon_id       Ensembl Exon ID       feature_page
# 5 description           Description           feature_page
#     name                            description
# 1   ensembl_gene_id                 Ensembl Gene ID
# 2   ensembl_transcript_id           Ensembl Transcript ID
# 3   ensembl_peptide_id              Ensembl Protein ID
# 4   ensembl_exon_id                 Ensembl Exon ID
# 5   description                     Description
# 6   chromosome_name                 Chromosome Name
# 7   start_position                  Gene Start (bp)
# 8   end_position                    Gene End (bp)
# 9   strand                          Strand
# 10  band                            Band
# 11  transcript_start                Transcript Start (bp)
# 12  transcript_end                  Transcript End (bp)
# 13  transcription_start_site        Transcription Start Site (TSS)
# 14  transcript_length               Transcript length
# 15  transcript_tsl                  Transcript Support Level (TSL)
# 16  transcript_gencode_basic        GENCODE basic annotation
# 17  transcript_appris_pi            APPRIS principal isoform annotation
# 18  external_gene_name              Associated Gene Name
# 19  external_gene_source            Associated Gene Source
# 20  external_transcript_name        Associated Transcript Name
# 21  external_transcript_source_name Associated Transcript Source
# 22  transcript_count                Transcript count
# 23  percentage_gc_content           % GC content
# 24  gene_biotype                    Gene type
# 25  transcript_biotype              Transcript type
# 26  source                          Source (gene)
# 27  transcript_source               Source (transcript)
# 28  status                          Status (gene)
# 29  transcript_status               Status (transcript)
# 30  version                         Version (gene)
# ... ...                             ...
# 48  sgd_gene                        SGD Gene
# 49  sgd_transcript                  SGD Transcript
# 50  uniparc                         UniParc
# 51  uniprot_sptrembl                UniProt/TrEMBL Accession
# 52  uniprot_swissprot               UniProt/SwissProt ID
# 53  uniprot_swissprot_accession     UniProt/SwissProt Accession
# 54  wikigene_name                   WikiGene Name
# 55  wikigene_id                     WikiGene ID
# 56  wikigene_description            WikiGene Description
# 57  affy_yeast_2                    Affy yeast 2 probeset
# 58  affy_yg_s98                     Affy yg s98 probeset
# 59  family                          Ensembl Protein Family ID(s)
# 60  family_description              Ensembl Family Description
# 61  pirsf                           PIRSF SuperFamily ID
# 62  superfamily                     Superfamily ID
# 63  smart                           SMART ID
# 64  profile                         PROFILE ID
# 65  prosite                         PROSITE ID
# 66  prints                          PRINTS ID
# 67  pfam                            PFAM ID
# 68  tigrfam                         TIGRFam ID
# 69  gene3d                          Gene3D ID
# 70  hmmpanther                      HMMPanther ID
# 71  interpro                        Interpro ID
# 72  interpro_short_description      Interpro Short Description
# 73  interpro_description            Interpro Description
# 74  low_complexity                  Low complexity
# 75  transmembrane_domain            Transmembrane domain
# 76  signal_domain                   Signal domain
# 77  ncoils                          Ncoils
#     page
# 1   feature_page
# 2   feature_page
# 3   feature_page
# 4   feature_page
# 5   feature_page
# 6   feature_page
# 7   feature_page
# 8   feature_page
# 9   feature_page
# 10  feature_page
# 11  feature_page
# 12  feature_page
# 13  feature_page
# 14  feature_page
# 15  feature_page
# 16  feature_page
# 17  feature_page
# 18  feature_page
# 19  feature_page
# 20  feature_page
# 21  feature_page
# 22  feature_page
# 23  feature_page
# 24  feature_page
# 25  feature_page
# 26  feature_page
# 27  feature_page
# 28  feature_page
# 29  feature_page
# 30  feature_page
# ... ...
# 48  feature_page
# 49  feature_page
# 50  feature_page
# 51  feature_page
# 52  feature_page
# 53  feature_page
# 54  feature_page
# 55  feature_page
# 56  feature_page
# 57  feature_page
# 58  feature_page
# 59  feature_page
# 60  feature_page
# 61  feature_page
# 62  feature_page
# 63  feature_page
# 64  feature_page
# 65  feature_page
# 66  feature_page
# 67  feature_page
# 68  feature_page
# 69  feature_page
# 70  feature_page
# 71  feature_page
# 72  feature_page
# 73  feature_page
# 74  feature_page
# 75  feature_page
# 76  feature_page
# 77  feature_page
# [1] 3
# [1] 41  3
# [1] "data.frame"
#    ensembl_gene_id external_gene_name ensembl_peptide_id
# 1  YGR055W         MUP1               YGR055W
# 2  YMR161W         HLJ1               YMR161W
# 3  YJR126C         VPS70              YJR126C
# 4  YDR272W         GLO2               YDR272W
# 5  YOR337W         TEA1               YOR337W
# 6  YOR032C         HMS1               YOR032C
# 7  YGR197C         SNG1               YGR197C
# 8  YHL019C         APM2               YHL019C
# 9  YBL052C         SAS3               YBL052C
# 10 YDR502C         SAM2               YDR502C
# 11 YNL077W         APJ1               YNL077W
# 12 YIL124W         AYR1               YIL124W
# 13 YGR234W         YHB1               YGR234W
# 14 YBL067C         UBP13              YBL067C
# 15 YOR188W         MSB1               YOR188W
# 16 YOL049W         GSH2               YOL049W
# 17 YEL042W         GDA1               YEL042W
# 18 YIL117C         PRM5               YIL117C
# 19 YBR203W         COS111             YBR203W
# 20 YIR030C         DCG1               YIR030C
# 21 YPL067C                            YPL067C
# 22 YHL024W         RIM4               YHL024W
# 23 YDR100W         TVP15              YDR100W
# 24 YHR006W         STP2               YHR006W
# 25 YER037W         PHM8               YER037W
# 26 YIL125W         KGD1               YIL125W
# 27 YJL172W         CPS1               YJL172W
# 28 YDR528W         HLR1               YDR528W
# 29 YGL164C         YRB30              YGL164C
# 30 YMR160W                            YMR160W
# 31 YMR175W         SIP18              YMR175W
# 32 YKR017C                            YKR017C
# 33 YOL151W         GRE2               YOL151W
# 34 YDR519W         FPR2               YDR519W
# 35 YGL224C         SDT1               YGL224C
# 36 YDR315C         IPK1               YDR315C
# 37 YFR014C         CMK1               YFR014C
# 38 YGR015C                            YGR015C
# 39 YJR107W                            YJR107W
# 40 YCR005C         CIT2               YCR005C
# 41 YOR292C                            YOR292C
#    ensembl_gene_id external_gene_name ensembl_peptide_id
# 1  YGR055W         MUP1               YGR055W
# 2  YMR161W         HLJ1               YMR161W
# 3  YJR126C         VPS70              YJR126C
# 4  YDR272W         GLO2               YDR272W
# 5  YOR337W         TEA1               YOR337W
# 6  YOR032C         HMS1               YOR032C
# 7  YGR197C         SNG1               YGR197C
# 8  YHL019C         APM2               YHL019C
# 9  YBL052C         SAS3               YBL052C
# 10 YDR502C         SAM2               YDR502C
# 11 YNL077W         APJ1               YNL077W
# 12 YIL124W         AYR1               YIL124W
# 13 YGR234W         YHB1               YGR234W
# 14 YBL067C         UBP13              YBL067C
# 15 YOR188W         MSB1               YOR188W
# 16 YOL049W         GSH2               YOL049W
# 17 YEL042W         GDA1               YEL042W
# 18 YIL117C         PRM5               YIL117C
# 19 YBR203W         COS111             YBR203W
# 20 YIR030C         DCG1               YIR030C
# 21 YPL067C                            YPL067C
# 22 YHL024W         RIM4               YHL024W
# 23 YDR100W         TVP15              YDR100W
# 24 YHR006W         STP2               YHR006W
# 25 YER037W         PHM8               YER037W
# 26 YIL125W         KGD1               YIL125W
# 27 YJL172W         CPS1               YJL172W
# 28 YDR528W         HLR1               YDR528W
# 29 YGL164C         YRB30              YGL164C
# 30 YMR160W                            YMR160W
# 31 YMR175W         SIP18              YMR175W
# 32 YKR017C                            YKR017C
# 33 YOL151W         GRE2               YOL151W
# 34 YDR519W         FPR2               YDR519W
# 35 YGL224C         SDT1               YGL224C
# 36 YDR315C         IPK1               YDR315C
# 37 YFR014C         CMK1               YFR014C
# 38 YGR015C                            YGR015C
# 39 YJR107W                            YJR107W
# 40 YCR005C         CIT2               YCR005C
# 41 YOR292C                            YOR292C
# [1] 41  3
# $YGR055W
# [1] "ENSP00000023064"
#
# $YMR161W
# [1] NA
#
# $YJR126C
# [1] NA
#
# $YDR272W
# [1] NA
#
# $YOR337W
# [1] NA
#
# $YOR032C
# [1] NA
#
# $YGR197C
# [1] NA
#
# $YHL019C
# [1] NA
#
# $YBL052C
# [1] NA
#
# $YDR502C
# [1] NA
#
# $YNL077W
# [1] NA
#
# $YIL124W
# [1] NA
#
# $YGR234W
# [1] NA
#
# $YBL067C
# [1] NA
#
# $YOR188W
# [1] NA
#
# $YOL049W
# [1] "ENSP00000216951"
#
# $YEL042W
# [1] NA
#
# $YIL117C
# [1] NA
#
# $YBR203W
# [1] NA
#
# $YIR030C
# [1] NA
#
# $YPL067C
# [1] NA
#
# $YHL024W
# [1] NA
#
# $YDR100W
# [1] NA
#
# $YHR006W
# [1] NA
#
# $YER037W
# [1] NA
#
# $YIL125W
# [1] NA
#
# $YJL172W
# [1] "ENSP00000356104"
#
# $YDR528W
# [1] NA
#
# $YGL164C
# [1] NA
#
# $YMR160W
# [1] NA
#
# $YMR175W
# [1] NA
#
# $YKR017C
# [1] NA
#
# $YOL151W
# [1] NA
#
# $YDR519W
# [1] NA
#
# $YGL224C
# [1] NA
#
# $YDR315C
# [1] NA
#
# $YFR014C
# [1] NA
#
# $YGR015C
# [1] NA
#
# $YJR107W
# [1] NA
#
# $YCR005C
# [1] NA
#
# $YOR292C
# [1] NA
# [1] "list"
# $YGR055W
# [1] "ENSP00000023064"
#
# $YOL049W
# [1] "ENSP00000216951"
#
# $YJL172W
# [1] "ENSP00000356104"
# [1] 3
#   ensembl_gene_id hgnc_symbol ensembl_peptide_id entrezgene
# 1 ENSG00000021488 SLC7A9      ENSP00000023064     11136
# 2 ENSG00000100983 GSS         ENSP00000216951      2937
# 3 ENSG00000162877 PM20D1      ENSP00000356104    148811
# [1] 3 4
# R version 3.3.1 (2016-06-21)
# Platform: x86_64-w64-mingw32/x64 (64-bit)
# Running under: Windows 10 x64 (build 14393)
#
# locale:
# [1] LC_COLLATE=English_United States.1252
# [2] LC_CTYPE=English_United States.1252
# [3] LC_MONETARY=English_United States.1252
# [4] LC_NUMERIC=C
# [5] LC_TIME=English_United States.1252
#
# attached base packages:
# [1] parallel  stats4    stats     graphics  grDevices utils     datasets
# [8] methods   base
#
# other attached packages:
# [1] plyr_1.8.4           biomaRt_2.30.0       hom.Sc.inp.db_3.1.2
# [4] AnnotationDbi_1.36.2 IRanges_2.8.2        S4Vectors_0.12.2
# [7] Biobase_2.34.0       BiocGenerics_0.20.0  BiocInstaller_1.24.0
#
# loaded via a namespace (and not attached):
#  [1] Rcpp_0.12.10        magrittr_1.5        uuid_0.1-2
#  [4] R6_2.2.0            stringr_1.2.0       tools_3.3.1
#  [7] DBI_0.6-1           digest_0.6.12       crayon_1.3.2
# [10] IRdisplay_0.4.4     repr_0.12.0         bitops_1.0-6
# [13] RCurl_1.95-4.8      IRkernel_0.8.6.9000 memoise_1.0.0
# [16] evaluate_0.10       RSQLite_1.1-2       pbdZMQ_0.2-5
# [19] stringi_1.1.5       XML_3.98-1.6        jsonlite_1.4
